# %% [markdown]
# ## Installing libraries

# %%
# ! pip install jupyter-lab
# ! pip install jupyterlab_sql
# ! jupyter lab build
# ! pip install scrapy
# ! pip install sqlalchemy

# %%
# https://github.com/vega/ipyvega/blob/master/notebooks/VegaLite.ipynb

# %% [markdown]
# ## Importing libs

# %%
import requests
from scrapy import Selector
from bs4 import BeautifulSoup as bs
import pandas as pd

# %% [markdown]
# #### install chrome extension
# * https://chrome.google.com/webstore/detail/selectorgadget/mhjhnkcfbdhnjickkkdbjoemdmbfginb?hl=en

# %% [markdown]
# ## Jupyter Lab
# * https://www.datacamp.com/community/tutorials/sql-interface-within-jupyterlab

# %% [markdown]
# # Scrapy

# %% [markdown]
# #### Scrapy shell: test selectors
#
# * ! scrapy shell 'http://quotes.toscrape.com'
# * ! fetch('http://quotes.toscrape.com')
# * ! response.css()

# %% [markdown]
# ## Selectors

# %%
url = 'http://quotes.toscrape.com'

# %%
quotes = requests.get(url).content

# %%
sel_quotes = Selector(text=quotes)

# %%
type(sel_quotes)
# Out:
# scrapy.selector.unified.Selector

# %%
# print all the elements
len(sel_quotes.xpath('//*'))
# Out:
# 151

# %%
# sel.css()
# sel.xpath()

# %%
sel_quotes.xpath('//*[contains(concat( " ", @class, " " ), concat( " ", "author", " " ))]//text()').extract()
# Out:
# ['Albert Einstein',
#  'J.K. Rowling',
#  'Albert Einstein',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Albert Einstein',
#  'André Gide',
#  'Thomas A. Edison',
#  'Eleanor Roosevelt',
#  'Steve Martin']

# %%
sel_quotes.css('.text::text').extract()
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”']

# %% [markdown]
# ### Translate xpath to CSS

# %%
# Create the XPath string equivalent to the CSS Locator 
xpath = '/html/body/span[1]//a'

# Create the CSS Locator string equivalent to the XPath
css_locator = 'html > body > span:nth-of-type(1) a'

# %%
# Create the XPath string equivalent to the CSS Locator 
xpath = '//div[@id="uid"]/span//h4'

# Create the CSS Locator string equivalent to the XPath
css_locator = 'div#uid > span h4'

# %% [markdown]
# ### Exemplo

# %%
uol_link = 'https://www.uol.com.br/'

# %%
uol = requests.get(uol_link).content

# %%
uol_sel = Selector(text=uol)

# %%
news = uol_sel.css('.color2::text').extract()

# %% [markdown]
# ### Twitter

# %%
twitter_link = 'https://twitter.com/Twitter?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor'

# %%
twitter = requests.get(twitter_link).content

# %%
tw_sel = Selector(text=twitter)

# %%
xpath_selector = '//div/p[@class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text"]/text()'

# %%
tweets = tw_sel.xpath(xpath_selector).extract()

# %%
len(tweets)
# Out:
# 29

# %%
likes = tw_sel.css('.r-qvutc0')

# %%
likes
# Out:
# []

# %% [markdown]
# ## A little bit of text processing

# %%
# visualize the most mentioned features

import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud

def word_cloud_figure(col,
            max_words=None,
            background_color='white',
            stopwords=None):
    string_text = str(col)
    wordCloud = WordCloud(max_words=max_words,
                        repeat=False,
                        stopwords=stopwords,
                        background_color=background_color
                        ).generate(string_text)
    plt.figure(figsize=(10,7))
    plt.imshow(wordCloud, interpolation='bilinear')
    plt.axis('off')
    return(plt.show())

# %%
word_cloud_figure(news)

# %% [markdown]
# #### pygsheets

# %%
import pygsheets
from nltk.corpus import stopwords

def stop_words_gsheet():
    url = '/Users/liviaclarete/gdrive/code/functions/gdocs/googleKey_pesq7/client_secret.json'
    # reading stopwords from a google sheet
    gc = pygsheets.authorize(client_secret=url)
    # Open spreadsheet and then workseet
    sh = gc.open('stopwords_pt')
    wks = sh.sheet1
    # get the values
    stopwords_m = wks.get_all_values(returnas='matrix')
    # create a list with stopwords
    sheet_stopwords = [i[0] for i in stopwords_m]
    # loading nltk stopwords
    stop = stopwords.words('portuguese')
    stopwords_total = stop + sheet_stopwords
    return(stop)

# %%
# https://docs.google.com/spreadsheets/d/1GLMt63E9a-EdT-_igqXDvrLb4tf64bW_LTRLSFP2JbQ/edit#gid=1713228162

# %%
stwords = stop_words_gsheet()

# %%
stwords = stwords + ['do', 'no', 'a', 'o', 'com', 'por', 'em', 'de', 'sobre', 'diz', 'da', 'é', 'como', 'que', 'dentro', 
                     'Após', 'diz', 'Entenda', 'dentro', 'ainda', 'contra', 'Brasil', 'caso', 'cada']

# %%
stwords[0]
# Out:
# 'de'

# %%
word_cloud_figure(news, stopwords=stwords)

# %% [markdown]
# ### pre-processing

# %%
news_df = pd.DataFrame(news)

# %%
news_df.columns = ['news']

# %%
stwords = stwords

# %%
def pre_processing_col(col, stopwords=stwords):
    # transform the words into lower case
    col = col.apply(lambda x: x.lower())
    # removing punctuation
    col = col.str.replace('[^\w\s]', '')
    # removing numbers
    col = col.apply(
    # iterate through each item in a returns a list of words and joins the split words into a sentence again
    lambda x:' '.join([x for x in x.split() if not x.isdigit()]))
    # stopwords
    # removing stopwords
    col = col.apply(lambda x: ' '.join([x for x in x.split() if x not in stopwords]))
    return(col)

# %%
news_df['news_clean'] = pre_processing_col(news_df.news)

# %%
from textblob import TextBlob

# tokenize words from the text
def tokenization(col):
    serie = pd.Series(col.apply(lambda x:x.split()))
    return(serie)

# %%
news_df['token'] = tokenization(news_df.news_clean)

# %%
news_df.head()
# Out:
#                                                 news  \
# 0  Descanso aos domingos voltará a ser a cada 4 s...
# 1  Análise: 9 razões para o trabalhador se preocu...
# 2  Protestos pelo Brasil contra cortes na educaçã...
# 3  'Rei dos fiscais' de SP é condenado a 54 anos ...
# 4  Justiça vive fase de parcialidade, bajulação e...
#
#                                           news_clean  \
# 0   descanso domingos voltará ser semanas mp relator
# 1  análise razões trabalhador preocupar medida pr...
# 2  protestos brasil cortes educação criticam prog...
# 3     rei fiscais sp condenado anos cobrança propina
# 4  justiça vive fase parcialidade bajulação polit...
#
#                                                token
# 0  [descanso, domingos, voltará, ser, semanas, mp...
# 1  [análise, razões, trabalhador, preocupar, medi...
# 2  [protestos, brasil, cortes, educação, criticam...
# 3  [rei, fiscais, sp, condenado, anos, cobrança, ...
# 4  [justiça, vive, fase, parcialidade, bajulação,...

# %%
import gensim
from gensim import corpora


# Creating a term dictionary of the text corpus
dictionary = corpora.Dictionary(news_df.token)

# %%
# creating a Document Text Matrix with the dictionary
doc_term_matrix = [dictionary.doc2bow(i) for i in news_df['token'] ]

# %%
# Creating the object for LDA model using gensim library
LDA = gensim.models.ldamodel.LdaModel

# Build LDA model
lda_model = LDA(corpus=doc_term_matrix,
                id2word=dictionary,
                num_topics=4, 
                random_state=100)

# %%
# Printing the topics
lda_model.print_topics()
# Out:
# [(0,
#   '0.010*"r" + 0.010*"daniel" + 0.010*"vira" + 0.010*"maior" + 0.010*"janela" + 0.010*"falar" + 0.010*"história" + 0.010*"queen" + 0.010*"supremo" + 0.010*"sucesso"'),
#  (1,
#   '0.016*"r" + 0.016*"após" + 0.016*"nada" + 0.009*"críticas" + 0.009*"bolsonaro" + 0.009*"relator" + 0.009*"ação" + 0.009*"sadio" + 0.009*"globo" + 0.009*"sob"'),
#  (2,
#   '0.016*"bolsonaro" + 0.009*"governo" + 0.009*"brasil" + 0.009*"abre" + 0.009*"atuarem" + 0.009*"tilt" + 0.009*"dani" + 0.009*"via" + 0.009*"voice" + 0.009*"oficialmente"'),
#  (3,
#   '0.014*"anos" + 0.013*"brasil" + 0.013*"justiça" + 0.008*"carlos" + 0.008*"biochip" + 0.008*"cartão" + 0.008*"total" + 0.008*"joão" + 0.008*"implantado" + 0.008*"viver"')]

# %%
# http://www.kennyshirley.com/LDAvis/#topic=0&lambda=0.66&term=
# https://www.objectorientedsubject.net/2018/08/experiments-on-topic-modeling-pyldavis/
# https://datascienceplus.com/evaluation-of-topic-modeling-topic-coherence/

# %%
import pyLDAvis
import pyLDAvis.gensim

# Downalod dictionaries from spacy -- lemmatization
# !python -m spacy download en # one time run
# !python -m spacy download pt # one time run

import matplotlib.pyplot as plt
import seaborn as sns

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.113571  0.004143       1        1  32.427288
# 2      0.045063 -0.095386       2        1  25.119019
# 1      0.062413  0.074802       3        1  24.229527
# 0      0.006095  0.016441       4        1  18.224169, topic_info=    Category      Freq       Term     Total  loglift  logprob
# 142  Default  1.000000          r  1.000000  30.0000  30.0000
# 257  Default  1.000000       após  1.000000  29.0000  29.0000
# 205  Default  1.000000       nada  1.000000  28.0000  28.0000
# 72   Default  2.000000  bolsonaro  2.000000  27.0000  27.0000
# 144  Default  0.000000       vira  0.000000  26.0000  26.0000
# ..       ...       ...        ...       ...      ...      ...
# 161   Topic4  0.550482  fodástico  0.954550   1.1520  -4.5781
# 271   Topic4  0.550397     recebe  0.954599   1.1518  -4.5783
# 174   Topic4  0.550350      grazi  0.954556   1.1517  -4.5784
# 142   Topic4  0.556177          r  1.957697   0.4440  -4.5678
# 111   Topic4  0.552858     daniel  1.528709   0.6853  -4.5738
#
# [161 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 223       2  0.973662      abertas
# 121       2  0.973614         abre
# 52        1  0.921889        adeus
# 109       4  1.047845       adiada
# 233       1  0.921952        agora
# ...     ...       ...          ...
# 61        1  0.921846        viver
# 120       2  0.973658        voice
# 6         3  0.988510      voltará
# 272       4  1.047659  whindersson
# 276       3  0.988519        órgão
#
# [136 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 2, 1])

# %% [markdown]
# ### Are we allowed to scrape?
# https://www.facebook.com/robots.txt

# %% [markdown]
# # Let's go to scrapy!

# %% [markdown]
# ├── scrapy.cfg                # deploy configuration file
# └── scrapy_spider             # project's Python module, you'll import your code from here
#     ├── __init__.py
#     ├── items.py              # project items definition file
#     ├── middlewares.py        # project middlewares file
#     ├── pipelines.py          # project pipeline file
#     ├── settings.py           # project settings file
#     └── spiders               # a directory where spiders are located
#         ├── __init__.py
#         └── example.py        # spider we just created

# %% [markdown]
# ## Scrapy flow
#
#
# * create a project
#     >scrapy startproject __project_name__
#
# * go to the project's directory
#     > cd __project_name__
#
# * create a spider
#     > scrapy genspider __spider_name__ __url_to_be_scraped__
#
# * Go to the 'spider' folder
#     > scrapy genspider __spider_name__ 'www.page.com'
# * Modify the file
#     >* Open the spider spider_file.py
#
# * scrapy runspider spider_file.py -o file.csv

# %% [markdown]
# ## spiders

# %%
# -*- coding: utf-8 -*-
import scrapy

class QuotesSpiderSpider(scrapy.Spider):
    name = 'quotes_spider'
    allowed_domains = ['quotes.toscrape.com']
    start_urls = ['http://quotes.toscrape.com/']

    def parse(self, response):
        pass

# %% [markdown]
# Spider paramethers
#
# * name: identifies the Spider. It must be unique within a project
#
# * start_urls: The list of the feed URLs, the spider would start by crawling the feed URLs.
#
# * allowed_domains: This setting is useful for broad crawls, if the domain of the URL is not in this setting, then the URL would be ignored.
#
# * parse: a method that will be called to handle the response downloaded for each of the requests made.

# %%
import scrapy

class QuotesSpiderSpider(scrapy.Spider):
    name = 'quotes_spider'
    allowed_domains = ['quotes.toscrape.com']
    start_urls = ['http://quotes.toscrape.com/']

    def parse(self, response):
        quotes = response.xpath("//div[@class='quote']//span[@class='text']/text()").extract()
        yield {'quotes': quotes}

# %%
path = '/Users/liviaclarete/Documents/june2019-ft/quotes/quotes/spiders/'

# %%
quotes_1_path = path + 'quotes.csv'

# %%
quotes = pd.read_csv(quotes_1, sep=',')

# %%
quotes
# Out:
#                                               quotes
# 0  “The world as we have created it is a process ...

# %%
class QuotesSpiderSpider(scrapy.Spider):
    name = 'quotes_spider'
    allowed_domains = ['quotes.toscrape.com']
    start_urls = ['http://quotes.toscrape.com/']

    def parse(self, response):
        quotes = response.xpath("//div[@class='quote']")
        for quote in quotes:
            text = quote.xpath(
                ".//span[@class='text']/text()").extract_first()
            author = quote.xpath(
                ".//small//text()").extract_first()
            yield {'quote': text, "author": author}

# %%
quotes_2_path = path + 'quotes_2.csv'

# %%
quotes2 = pd.read_csv(quotes_2_path)

# %%
quotes2
# Out:
#                                                quote             author
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. I've just found 10,000 way...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin

# %%
class QuotesSpiderSpider(scrapy.Spider):
    name = 'quotes_spider'
    allowed_domains = ['quotes.toscrape.com']
    start_urls = ['http://quotes.toscrape.com/']

    def parse(self, response):
        quotes = response.xpath("//div[@class='quote']")
        for quote in quotes:
            text = quote.xpath(
                ".//span[@class='text']/text()").extract_first()
            author = quote.xpath(
                ".//small//text()").extract_first()
            yield {'quote': text, "author": author}

        next_page_url = response.xpath("//li[@class='next']//a/@href").extract_first()
        if next_page_url:
            absolute_next_page_url = response.urljoin(next_page_url)
            yield scrapy.Request(absolute_next_page_url)

# %%
quotes_3_path = path + 'quotes_3.csv'

# %%
quotes3 = pd.read_csv(quotes_3_path)

# %%
quotes3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6e4d512dcad2> in <module>
# ----> 1 quotes3.head()
#
# NameError: name 'quotes3' is not defined
