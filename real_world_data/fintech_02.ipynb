# %%
from zipfile import ZipFile
import pandas as pd

# %%
! wget http://databank.worldbank.org/data/download/FINDEX_CSV.zip
# Out:
# --2019-07-01 12:03:07--  http://databank.worldbank.org/data/download/FINDEX_CSV.zip
# Resolving databank.worldbank.org... 192.86.98.102
# Connecting to databank.worldbank.org|192.86.98.102|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://databank.worldbank.org/data/download/FINDEX_CSV.zip [following]
# --2019-07-01 12:03:07--  https://databank.worldbank.org/data/download/FINDEX_CSV.zip
# Connecting to databank.worldbank.org|192.86.98.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 427 [text/html]
# Saving to: ‘FINDEX_CSV.zip’
#
# FINDEX_CSV.zip      100%[===================>]     427  --.-KB/s    in 0s
#
# 2019-07-01 12:03:08 (12.7 MB/s) - ‘FINDEX_CSV.zip’ saved [427/427]

# %%
# unzip the file
path_to_zip_file = ('FINDEX_CSV.zip')

# %%
zf = ZipFile(path_to_zip_file, 'r')
zf.extractall('\FINDEX_CSV\FINDEXCountry-Series.csv')

# %%
global_inclusion = pd.read_excel('FINDEXEXCEL.xlsx')

# %%
global_inclusion
# Out:
#                                    Country Name Country Code  \
# 0       Central America (excluding high income)          CAM
# 1       Central America (excluding high income)          CAM
# 2       Central America (excluding high income)          CAM
# 3       Central America (excluding high income)          CAM
# 4       Central America (excluding high income)          CAM
# 5       Central America (excluding high income)          CAM
# 6       Central America (excluding high income)          CAM
# 7       Central America (excluding high income)          CAM
# 8       Central America (excluding high income)          CAM
# 9       Central America (excluding high income)          CAM
# 10      Central America (excluding high income)          CAM
# 11      Central America (excluding high income)          CAM
# 12      Central America (excluding high income)          CAM
# 13      Central America (excluding high income)          CAM
# ...
