# %% [markdown]
# ![IronHack Logo](https://s3-eu-west-1.amazonaws.com/ih-materials/uploads/upload_d5c5793015fec3be28a63c4fa3dd4d55.png)
#
# # Project: Data Cleaning and Manipulation with Pandas
#
# ## Overview
#
# The goal of this project is to combine everything you have learned about data wrangling, cleaning, and manipulation with Pandas so you can see how it all works together. For this project, you will start with this messy data set [Shark Attack](https://www.kaggle.com/teajay/global-shark-attacks/version/1). You will need to import it, use your data wrangling skills to clean it up, prepare it to be analyzed, and then export it as a clean CSV data file.
#
# **You will be working individually for this project**, but we'll be guiding you along the process and helping you as you go. Show us what you've got!
#
#
# ---
#
# ## Technical Requirements
#
# The technical requirements for this project are as follows:
#
# * The dataset that we provide you is a significantly messy data set. Apply the different cleaning and manipulation techniques you have learned.
# * Import the data using Pandas.
# * Examine the data for potential issues.
# * Use at least 8 of the cleaning and manipulation methods you have learned on the data.
# * Produce a Jupyter Notebook that shows the steps you took and the code you used to clean and transform your data set.
# * Export a clean CSV version of your data using Pandas.
#
# ## Necessary Deliverables
#
# The following deliverables should be pushed to your Github repo for this chapter.
#
# * **A cleaned CSV data file** containing the results of your data wrangling work.
# * **A Jupyter Notebook (data-wrangling.ipynb)** containing all Python code and commands used in the importing, cleaning, manipulation, and exporting of your data set.
# * **A ``README.md`` file** containing a detailed explanation of the process followed in the importing, cleaning, manipulation, and exporting of your data as well as your results, obstacles encountered, and lessons learned.
#
# ## Suggested Ways to Get Started
#
# * **Examine the data and try to understand what the fields mean** before diving into data cleaning and manipulation methods.
# * **Break the project down into different steps** - use the topics covered in the lessons to form a check list, add anything else you can think of that may be wrong with your data set, and then work through the check list.
# * **Use the tools in your tool kit** - your knowledge of Python, data structures, Pandas, and data wrangling.
# * **Work through the lessons in class** & ask questions when you need to! Think about adding relevant code to your project each night, instead of, you know... _procrastinating_.
# * **Commit early, commit often**, don’t be afraid of doing something incorrectly because you can always roll back to a previous version.
# * **Consult documentation and resources provided** to better understand the tools you are using and how to accomplish what you want.
#
# ## Useful Resources
#
# * [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/)
# * [Pandas Tutorials](https://pandas.pydata.org/pandas-docs/stable/tutorials.html)
# * [StackOverflow Pandas Questions](https://stackoverflow.com/questions/tagged/pandas)
# * [Awesome Public Data Sets](https://github.com/awesomedata/awesome-public-datasets)
# * [Kaggle Data Sets](https://www.kaggle.com/datasets)

# %% [markdown]
# ## Histories
# ### A case
#
# https://www.theguardian.com/environment/2019/jan/03/shark-attack-bitten-great-white-survivors-near-death-experience

# %% [markdown]
# ### "Instead of ignoring the problem or pretending that we can put up nets and protect everyone from sharks, what is needed is a public education campaign to teach people how to co-exist with sharks," Lewis Levine, M.D.

# %% [markdown]
# * Yet each year, for every human killed by a shark, our species slaughters millions of sharks - about 73 million sharks last year.

# %% [markdown]
# ### Mission
#
# * Global Shark Attack File to present facts about these events

# %% [markdown]
# ### Methodology
#
# * Early on, we became aware that the word "attack" was usually a misnomer. An "attack" by a shark is an extremely rare event, even less likely than statistics suggest. When a shark bites a surfboard, leaving the surfer unharmed, it was historically recorded as an "attack". Collisions between humans and sharks in low visibility water were also recorded as "attacks";
#
# * Although incidents that occur in remote areas may go unrecorded, the Global Shark Attack File is a compilation of a number of data sources, and we have a team of qualified researchers throughout the world that actively investigate these incidents. One of our objectives is to provide a clear picture of the actual threat presented by sharks to humans. In this regard, we remind our visitors that more people drown in a single year in the United States than have been killed by sharks throughout the entire world in the last two centuries.
#
#
#
# https://www.floridamuseum.ufl.edu/shark-attacks/yearly-worldwide-summary/

# %% [markdown]
# ### Dataset
#
# The International Shark Attack File is a global database of shark attacks. It began as an attempt to catalogue shark attacks on servicemen during World War II. The Office of Naval Research funded it from 1958 until 1968. During that time, a panel of shark experts developed a standard system for collecting accounts of shark attacks from around the world. The file was temporarily housed at the Mote Marine Laboratory in Sarasota, Florida, until a permanent home was found at the Florida Museum of Natural History at the University of Florida. It is currently under the direction of members of the American Elasmobranch Society, including George H. Burgess. The file contains information on over 5,300 shark attacks, and includes detailed, often privileged, information including autopsy reports and graphic photos. The file is accessible only to scientists whose access is permitted only by a review board.
#
# A similar project called Global Shark Attack File is accessible to everybody as an XLS file that can be sorted by date and location of the shark attack.[1]
#
# * http://www.sharkattackfile.net/incidentlog.htm

# %% [markdown]
# ### Categories
#
# *
# INCIDENTS INVOLVING BOATS – INCIDENTS IN WHICH A BOAT WAS BITTEN OR RAMMED BY A SHARK ARE IN GREEN.
#
# HOWEVER, IN CASES IN WHICH THE SHARK WAS HOOKED, NETTED OR GAFFED, THE ENTRY IS ORANGE BECAUSE THEY ARE CLASSED AS PROVOKED INCIDENTS.
#
# CASUALTIES OF WAR & AIR/SEA DISASTERS - SHARKS MAINTAIN THE HEALTH OF THE MARINE ECOSYSTEM BY REMOVING THE DEAD OR INJURED ANIMALS. MANY INCIDENTS RESULT BECAUSE, LIKE OTHER ANIMALS THAT DON'T RELY ON INSTINCT ALONE, SHARKS EXPLORE THEIR ENVIRONMENT. LACKING HANDS, THEY MAY INVESTIGATE AN UNFAMILIAR OBJECT WITH THEIR MOUTHS. UNLIKE HUMANS, THERE IS NO MALICE IN SHARKS; THEY SIMPLY DO WHAT NATURE DESIGNED THEM TO DO. AIR/SEA DISASTERS ARE ACCIDENTS THAT PLACE PEOPLE INTO THE DAY-TO-DAY BUSINESS OF SHARKS. THE WARTIME LOSSES DUE TO SHARKS RESULT FROM MANS' CRUELTY TO MAN. AIR/SEA DISASTERS ARE IN YELLOW.
#
# QUESTIONABLE INCIDENTS - INCIDENTS IN WHICH THERE ARE INSUFFICIENT DATA TO DETERMINE IF THE INJURY WAS CAUSED BY A SHARK OR THE PERSON DROWNED AND THE BODY WAS LATER SCAVENGED BY SHARKS. IN A FEW CASES, DESPITE MEDIA REPORTS TO THE CONTRARY, EVIDENCE INDICATED THERE WAS NO SHARK INVOLVEMENT WHATSOEVER. SUCH INCIDENTS ARE IN BLUE.
#
# http://www.sharkattackfile.net/incidentlog.htm

# %% [markdown]
# #### Help the sharks
# * https://www.sharkwater.com/shark-database/

# %% [markdown]
# #### shark profile
# https://www.shark.ch/Database/

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import the data using Pandas

# %%
# pdf source: http://sharkattackfile.net/spreadsheets/pdf_directory/

# %%
df = pd.read_csv(
    # file to be imported
    'attacks.csv',
    # encoding
    encoding='latin1',
    # na values
    na_values=['xx', 'NaN', '0']
)

# %%
df.head(1)
# Out:
#   Case Number         Date    Year     Type Country        Area  \
# 0  2018.06.25  25-Jun-2018  2018.0  Boating     USA  California
#
#                       Location  Activity         Name Sex      ...      \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F     ...
#
#       Species  Investigator or Source                   pdf  \
# 0  White shark       R. Collier, GSAF  2018.06.25-Wolfe.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
df.tail(1)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25722         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#           ...     Species  Investigator or Source  pdf href formula href  \
# 25722     ...          NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 25722           NaN           NaN            NaN         NaN         NaN
#
# [1 rows x 24 columns]

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
# Case Number               6301 non-null object
# Date                      6302 non-null object
# Year                      6175 non-null float64
# Type                      6298 non-null object
# Country                   6252 non-null object
# Area                      5847 non-null object
# Location                  5762 non-null object
# Activity                  5758 non-null object
# Name                      6092 non-null object
# Sex                       5737 non-null object
# Age                       3471 non-null object
# Injury                    6274 non-null object
# Fatal (Y/N)               5763 non-null object
# Time                      2948 non-null object
# Species                   3464 non-null object
# Investigator or Source    6285 non-null object
# pdf                       6302 non-null object
# href formula              6301 non-null object
# href                      6302 non-null object
# Case Number.1             6302 non-null object
# Case Number.2             6302 non-null object
# original order            6309 non-null float64
# Unnamed: 22               1 non-null object
# Unnamed: 23               2 non-null object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %% [markdown]
# ## Feature selection: working with columns

# %%
# rename columns
def rename_cols(cols):
    # lower the cases using the string method lower()
    cols = cols.str.lower()
    # replace values to normalize the column's name
    cols = cols.str.replace(' ', '_').str.replace(')','')
    cols = cols.str.replace(':', '_').str.replace('(', '')
    cols = cols.str.replace('.', '_').str.replace('/', '')
    return(cols)

# %%
# call the rename_cols() function with df.columns as an argument
df.columns = rename_cols(df.columns)

# %%
# select the first 17 coluns and slice it using brackets
df = df[df.columns[0:16]]

# %%
df.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#           species_          investigator_or_source
# 0      White shark                R. Collier, GSAF
# 1              NaN  K.McMurray, TrackingSharks.com
# 2              NaN  K.McMurray, TrackingSharks.com
# 3        2 m shark                  B. Myatt, GSAF
# 4  Tiger shark, 3m                       A .Kipper

# %%
df.shape
# Out:
# (25723, 16)

# %%
df.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex_', 'age', 'injury', 'fatal_yn', 'time',
#        'species_', 'investigator_or_source'],
#       dtype='object')

# %% [markdown]
# ## Missing values - NaN
# * How to define what data should be considered a NaN value?
# * How to check a NaN?
# * How to assing a NaN value?

# %%
# check the number of NaN values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# time                      22775
# species_                  22259
# age                       22252
# sex_                      19986
# activity                  19965
# location                  19961
# fatal_yn                  19960
# area                      19876
# name                      19631
# year                      19548
# country                   19471
# injury                    19449
# investigator_or_source    19438
# type                      19425
# case_number               19422
# date                      19421
# dtype: int64

# %%
df.shape
# Out:
# (25723, 16)

# %%
# drop rows all NaN values?
df = df.dropna(axis=0, how='all')

# %%
df.shape
# Out:
# (6302, 16)

# %%
# after dropping all NaN values, recheck the NaN values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# time                      3354
# species_                  2838
# age                       2831
# sex_                       565
# activity                   544
# location                   540
# fatal_yn                   539
# area                       455
# name                       210
# year                       127
# country                     50
# injury                      28
# investigator_or_source      17
# type                         4
# case_number                  1
# date                         0
# dtype: int64

# %% [markdown]
# ##### Analyse column by column
# Let's start with a question?
# - What column does represent a unique identity associated to each row -- like a unique ID for each case?
#
# First of all, it is important to imagine that each row represent just one case, a unique story that will be summed up to other stories in each row. It is called analysed by block.
#
# "The data talks about everyone, but not individually".

# %% [markdown]
# ###### let's test if the column 'case_number' could be this ID column
#
# * Grouping the same values into a frequency table, we notice that the value '0' appeared 2400 times

# %%
df.case_number.value_counts().head()
# Out:
# 2006.09.02      2
# 1923.00.00.a    2
# 1920.00.00.b    2
# 1990.05.10      2
# 1907.10.16.R    2
# Name: case_number, dtype: int64

# %% [markdown]
# * What is the use of a repeated ID, considering that each case_number should, in theory, represent a unique code for each row?
#
# Should we consider the '0' as a NaN value?

# %%
# We can check specific values using .iloc
# df.case_number.iloc[8697]

# %%
# Let's check what data type are we talking about?
# type(df.case_number.iloc[8697])

# %% [markdown]
# * As we can see, the '0' is not able to assume the role of an ID. Let's now check it the rows with '0' carries any meaningful data:

# %% [markdown]
# Considering the rows from the column 'case_number' that carries '0' on it, all the columns carries NaN values, as we notice below:

# %%
# selecting all values from case_number equal to 0, and sum the NaN values:
df[df.case_number == '0'].isnull().sum()
# Out:
# case_number               0
# date                      0
# year                      0
# type                      0
# country                   0
# area                      0
# location                  0
# activity                  0
# name                      0
# sex_                      0
# age                       0
# injury                    0
# fatal_yn                  0
# time                      0
# species_                  0
# investigator_or_source    0
# dtype: int64

# %% [markdown]
# * If all other columns carries NaN and the '0' is not useful, we can label them into NaN:

# %%
# Replace all '0' with np.nan
df.case_number[df.case_number == '0'] = np.nan

# %%
# check if the value were replaced -- as expected
# and it worked!
df.case_number.value_counts(ascending=False).head()
# Out:
# 2006.09.02      2
# 1923.00.00.a    2
# 1920.00.00.b    2
# 1990.05.10      2
# 1907.10.16.R    2
# Name: case_number, dtype: int64

# %% [markdown]
# * After we replaced all '0' from the column case_number to a np.nan values, we're ready to exclude them from the dataset using the dropna() function.

# %%
# Before that, let's check the data shape

# %%
df.shape
# Out:
# (6302, 16)

# %%
# Dropping all rows in which all the cases are NaN
df = df.dropna(axis=0, how='all')

# %%
# It worked! Again, we dropped out all the rows with all NaN values
df.shape
# Out:
# (6302, 16)

# %% [markdown]
# * After analying the column 'case_number', let's move forward to new columns

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# time                      3354
# species_                  2838
# age                       2831
# sex_                       565
# activity                   544
# location                   540
# fatal_yn                   539
# area                       455
# name                       210
# year                       127
# country                     50
# injury                      28
# investigator_or_source      17
# type                         4
# case_number                  1
# date                         0
# dtype: int64

# %% [markdown]
# * Let's check the 'date' column:

# %%
df.date.str.replace('Reported', '').str.replace('No date', '').str.replace('Between ', '')
# Out:
# 0                                             25-Jun-2018
# 1                                             18-Jun-2018
# 2                                             09-Jun-2018
# 3                                             08-Jun-2018
# 4                                             04-Jun-2018
# 5                                             03-Jun-2018
# 6                                             03-Jun-2018
# 7                                             27-May-2018
# 8                                             26-May-2018
# 9                                             26-May-2018
# 10                                            24-May-2018
# 11                                            21-May-2018
# 12                                            13-May-2018
# 13                                            13-May-2018
# 14                                               May 2018
# 15                                            12-May-2018
# 16                                            09-May-2018
# 17                                            30-Apr-2018
# 18                                            28-Apr-2018
# 19                                            28-Apr-2018
# 20                                            25-Apr-2018
# 21                                            25-Apr-2018
# 22                                            24-Apr-2018
# 23                                            23-Apr-2018
# 24                                            22-Apr-2018
# 25                                            19-Apr-2018
# 26                                            15-Apr-2018
# 27                                            15-Apr-2018
# 28                                            15-Apr-2018
# 29                                            15-Apr-2018
#                               ...
# 6272                                         World War II
# 6273                                          Before 1905
# 6274                              A few years before 1938
# 6275                                                  NaN
# 6276                                          Early 1930s
# 6277                                          Before 1927
# 6278                                          1918 & 1939
# 6279                                                  NaN
# 6280                                                  NaN
# 6281                                                  NaN
# 6282                                           1920 -1923
# 6283                                          Before 1921
# 6284                                          Before 1911
# 6285                                          Before 1921
# 6286                                          Before 1921
# 6287                                          Before 1917
# 6288                                   Before 17-Jul-1916
# 6289     (3 days after preceding incident) & prior to ...
# 6290                                   Before 19-Jul-1913
# 6291                                          Before 1911
# 6292                                           Circa 1862
# 6293                                          Before 1906
# 6294                                          Before 1906
# 6295                                          Before 1906
# 6296                                          Before 1906
# 6297                                          Before 1903
# 6298                                          Before 1903
# 6299                                            1900-1905
# 6300                                            1883-1889
# 6301                                            1845-1853
# Name: date, Length: 6302, dtype: object

# %%
df.date.iloc[6275]
# Out:
# 'No date'

# %% [markdown]
# * We can see that 'No date' represent a NaN, a value that does not represent a number -- despite not being portrayed as so.
#
# So now, our job is to build a list of NaN values. The list should be considered as a parameter while importing the file. Or we can exclude one bye one, as we did with the '0' from the column 'case_number'.

# %%
nan_values = ['No date']

# %%
df.date[df.date == 'No date'] = np.nan
# Out:
# /Users/liviaclarete/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.date[df.date == 'No date'] = np.nan
# Out:
# /Users/liviaclarete/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.date.value_counts()
# Out:
# 1957                    11
# 1942                     9
# 1956                     8
# 1950                     7
# 1941                     7
# 1958                     7
# 1949                     6
# 12-Apr-2001              5
# Aug-1956                 5
# 1955                     5
# 1959                     5
# 1954                     5
# No date, Before 1963     5
# 1970s                    5
# 1940                     5
# 05-Oct-2003              5
# 28-Jul-1995              5
# Oct-1960                 5
# 23-Jan-1970              4
# 27-Dec-2008              4
# 29-Apr-2017              4
# Before 1906              4
# 1995                     4
# 09-Jan-2010              4
# 1952                     4
# 27-Jul-1952              4
# Before 1958              4
# 1938                     4
# 1960                     4
# 28-Dec-2014              4
#                         ..
# 18-Apr-2003              1
# 24-Oct-2009              1
# 27-Jul-1960              1
# 17-Apr-2008              1
# 15-Oct-1897              1
# 04-Mar-1956              1
# 19-Jun-1999              1
# 25-May-1975              1
# Ca. 1940                 1
# 11-Jun-2008              1
# 04-Mar-2012              1
# 18-May-1870              1
# 06-Feb-1955              1
# 18-Jun-1924              1
# Reported 22-Apr-1830     1
# 15-Feb-2010              1
# Reported 13-May-1947     1
# 02-Jul-1974              1
# 09-Apr-1962              1
# 31-May-1995              1
# 08-Jan-2005              1
# Early 1870s              1
# 27-Apr-1959              1
# 09-Jun-2018              1
# Jan-1963                 1
# 10-May-1908              1
# Reported 28-Aug-1884     1
# 21-Aug-1934              1
# 10-Apr-1988              1
# 01-Oct-2010              1
# Name: date, Length: 5432, dtype: int64

# %% [markdown]
# * Let's move to analyse the column 'year'

# %%
# We found 125 cases with '0.0', which is not a valid year
df.year.value_counts()
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 2008.0    122
# 2013.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1959.0     93
# 1960.0     93
# 2001.0     92
# 2003.0     92
# 2004.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1964.0     66
# 1999.0     66
# 1998.0     65
# 1963.0     61
# 1996.0     61
# 1966.0     58
# 1997.0     57
#          ...
# 1733.0      1
# 1859.0      1
# 1822.0      1
# 1815.0      1
# 1703.0      1
# 1748.0      1
# 1807.0      1
# 1580.0      1
# 1801.0      1
# 1802.0      1
# 1834.0      1
# 1638.0      1
# 1637.0      1
# 1784.0      1
# 1755.0      1
# 1767.0      1
# 1819.0      1
# 1738.0      1
# 1753.0      1
# 1783.0      1
# 1742.0      1
# 1816.0      1
# 1555.0      1
# 500.0       1
# 1721.0      1
# 1771.0      1
# 1791.0      1
# 1554.0      1
# 1823.0      1
# 1786.0      1
# Name: year, Length: 248, dtype: int64

# %%
# Checking value
df.year.iloc[6274]
# Out:
# nan

# %%
# Checking the type of 0.0 value
type(df.year.iloc[6274])
# Out:
# numpy.float64

# %%
# Let's transform the '0.0' value into a NaN
df.year[df.year == 0.0] = np.nan
# Out:
# /Users/liviaclarete/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# Let's check again
df.year.value_counts()
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 2008.0    122
# 2013.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1959.0     93
# 1960.0     93
# 2001.0     92
# 2003.0     92
# 2004.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1964.0     66
# 1999.0     66
# 1998.0     65
# 1963.0     61
# 1996.0     61
# 1966.0     58
# 1997.0     57
#          ...
# 1733.0      1
# 1859.0      1
# 1822.0      1
# 1815.0      1
# 1703.0      1
# 1748.0      1
# 1807.0      1
# 1580.0      1
# 1801.0      1
# 1802.0      1
# 1834.0      1
# 1638.0      1
# 1637.0      1
# 1784.0      1
# 1755.0      1
# 1767.0      1
# 1819.0      1
# 1738.0      1
# 1753.0      1
# 1783.0      1
# 1742.0      1
# 1816.0      1
# 1555.0      1
# 500.0       1
# 1721.0      1
# 1771.0      1
# 1791.0      1
# 1554.0      1
# 1823.0      1
# 1786.0      1
# Name: year, Length: 248, dtype: int64

# %%
df.year.isnull().sum()
# Out:
# 127

# %%
df2 = df.copy()

# %%
df2.index = df.year

# %%
df2
# Out:
#           case_number                                               date  \
# year
#  2018.0    2018.06.25                                        25-Jun-2018
#  2018.0    2018.06.18                                        18-Jun-2018
#  2018.0    2018.06.09                                        09-Jun-2018
#  2018.0    2018.06.08                                        08-Jun-2018
#  2018.0    2018.06.04                                        04-Jun-2018
#  2018.0  2018.06.03.b                                        03-Jun-2018
#  2018.0  2018.06.03.a                                        03-Jun-2018
#  2018.0    2018.05.27                                        27-May-2018
#  2018.0  2018.05.26.b                                        26-May-2018
#  2018.0  2018.05.26.a                                        26-May-2018
#  2018.0    2018.05.24                                        24-May-2018
#  2018.0    2018.05.21                                        21-May-2018
#  2018.0  2018.05.13.b                                        13-May-2018
#  2018.0  2018.05.13.a                                        13-May-2018
#  2018.0    2018.05.00                                           May 2018
#  2018.0    2018.05.12                                        12-May-2018
#  2018.0    2018.05.09                                        09-May-2018
#  2018.0  2018.04.30.R                               Reported 30-Apr-2018
#  2018.0  2018.04.28.b                                        28-Apr-2018
#  2018.0  2018.04.28.a                                        28-Apr-2018
#  2018.0  2018.04.25.b                                        25-Apr-2018
#  2018.0  2018.04.25.a                                        25-Apr-2018
#  2018.0    2018.04.24                                        24-Apr-2018
#  2018.0    2018.04.23                                        23-Apr-2018
#  2018.0    2018.04.22                                        22-Apr-2018
#  2018.0    2018.04.19                                        19-Apr-2018
#  2018.0  2018.04.15.d                                        15-Apr-2018
#  2018.0  2018.04.15.c                                        15-Apr-2018
#  2018.0  2018.04.15.b                                        15-Apr-2018
#  2018.0  2018.04.15.a                                        15-Apr-2018
# ...               ...                                                ...
# NaN           ND.0031                                       World War II
# NaN           ND.0030                                        Before 1905
# NaN           ND.0028                            A few years before 1938
# NaN           ND.0027                                                NaN
# NaN           ND.0026                                        Early 1930s
# NaN           ND.0025                                        Before 1927
# NaN           ND.0024                                Between 1918 & 1939
# NaN           ND.0023                                                NaN
# NaN           ND.0022                                                NaN
# NaN           ND.0021                                                NaN
# NaN           ND.0020                                         1920 -1923
# NaN           ND.0019                                        Before 1921
# NaN           ND.0018                                        Before 1911
# NaN           ND.0017                                        Before 1921
# NaN           ND.0016                                        Before 1921
# NaN           ND.0015                                        Before 1917
# NaN           ND.0014                                 Before 17-Jul-1916
# NaN           ND.0013  No date (3 days after preceding incident) & pr...
# NaN           ND.0012                                 Before 19-Jul-1913
# NaN           ND.0011                                        Before 1911
# NaN           ND.0010                                         Circa 1862
# NaN           ND.0009                                        Before 1906
# NaN           ND.0008                                        Before 1906
# NaN           ND.0007                                        Before 1906
# NaN           ND.0006                                        Before 1906
# NaN           ND.0005                                        Before 1903
# NaN           ND.0004                                        Before 1903
# NaN           ND.0003                                          1900-1905
# NaN           ND.0002                                          1883-1889
# NaN           ND.0001                                          1845-1853
#
#            year          type             country                       area  \
# year
#  2018.0  2018.0       Boating                 USA                 California
#  2018.0  2018.0    Unprovoked                 USA                    Georgia
#  2018.0  2018.0       Invalid                 USA                     Hawaii
#  2018.0  2018.0    Unprovoked           AUSTRALIA            New South Wales
#  2018.0  2018.0      Provoked              MEXICO                     Colima
#  2018.0  2018.0    Unprovoked           AUSTRALIA            New South Wales
#  2018.0  2018.0    Unprovoked              BRAZIL                 Pernambuco
#  2018.0  2018.0    Unprovoked                 USA                    Florida
#  2018.0  2018.0    Unprovoked                 USA                    Florida
#  2018.0  2018.0    Unprovoked                 USA                    Florida
#  2018.0  2018.0      Provoked           AUSTRALIA                 Queensland
#  2018.0  2018.0    Unprovoked                 USA             South Carolina
#  2018.0  2018.0    Unprovoked                 USA             South Carolina
#  2018.0  2018.0       Invalid             ENGLAND                   Cornwall
#  2018.0  2018.0      Provoked           AUSTRALIA          Westerm Australia
#  2018.0  2018.0    Unprovoked        SOUTH AFRICA      Eastern Cape Province
#  2018.0  2018.0  Questionable           AUSTRALIA            New South Wales
#  2018.0  2018.0    Unprovoked            THAILAND                    Hua Hin
#  2018.0  2018.0    Unprovoked          COSTA RICA               Cocos Island
#  2018.0  2018.0    Unprovoked           AUSTRALIA          Western Australia
#  2018.0  2018.0  Questionable           AUSTRALIA            New South Wales
#  2018.0  2018.0    Unprovoked           AUSTRALIA          Western Australia
#  2018.0  2018.0    Unprovoked           AUSTRALIA          Western Australia
#  2018.0  2018.0    Unprovoked            MALDIVES          Alifu Alifu Atoll
#  2018.0  2018.0    Unprovoked        SOUTH AFRICA      Western Cape Province
#  2018.0  2018.0    Unprovoked                 USA                     Hawaii
#  2018.0  2018.0    Unprovoked            THAILAND                    Hua Hin
#  2018.0  2018.0    Unprovoked              BRAZIL                 Pernambuco
#  2018.0  2018.0    Unprovoked           AUSTRALIA          Western Australia
#  2018.0  2018.0    Unprovoked           AUSTRALIA          Western Australia
# ...         ...           ...                 ...                        ...
# NaN         NaN  Sea Disaster    PAPUA NEW GUINEA            Madang Province
# NaN         NaN    Unprovoked               BURMA                        NaN
# NaN         NaN          Boat               ITALY               Adriatic Sea
# NaN         NaN    Unprovoked              GREECE         Dodecanese Islands
# NaN         NaN    Unprovoked              BELIZE                        NaN
# NaN         NaN    Unprovoked           AUSTRALIA            New South Wales
# NaN         NaN    Unprovoked             REUNION                Saint-Denis
# NaN         NaN    Unprovoked        SOUTH AFRICA      Western Cape Province
# NaN         NaN    Unprovoked           AUSTRALIA                        NaN
# NaN         NaN    Unprovoked        SOUTH AFRICA              KwaZulu-Natal
# NaN         NaN    Unprovoked           AUSTRALIA                 Queensland
# NaN         NaN    Unprovoked                 USA                    Florida
# NaN         NaN    Unprovoked             VIETNAM  Ba Ria-Vung Tau  Province
# NaN         NaN    Unprovoked        SOUTH AFRICA              KwaZulu-Natal
# NaN         NaN    Unprovoked        SOUTH AFRICA              KwaZulu-Natal
# NaN         NaN    Unprovoked                FIJI               Moala Island
# NaN         NaN    Unprovoked                 USA            North Carolina
# NaN         NaN    Unprovoked        SOUTH AFRICA              KwaZulu-Natal
# NaN         NaN    Unprovoked        SOUTH AFRICA              KwaZulu-Natal
# NaN         NaN    Unprovoked               ASIA?                        NaN
# NaN         NaN    Unprovoked                 USA                     Hawaii
# NaN         NaN    Unprovoked           AUSTRALIA                        NaN
# NaN         NaN    Unprovoked           AUSTRALIA                        NaN
# NaN         NaN    Unprovoked           AUSTRALIA                        NaN
# NaN         NaN    Unprovoked           AUSTRALIA            New South Wales
# NaN         NaN    Unprovoked           AUSTRALIA          Western Australia
# NaN         NaN    Unprovoked           AUSTRALIA          Western Australia
# NaN         NaN    Unprovoked                 USA             North Carolina
# NaN         NaN    Unprovoked              PANAMA                        NaN
# NaN         NaN    Unprovoked  CEYLON (SRI LANKA)           Eastern Province
#
#                                                   location  \
# year
#  2018.0                        Oceanside, San Diego County
#  2018.0                     St. Simon Island, Glynn County
#  2018.0                                       Habush, Oahu
#  2018.0                                 Arrawarra Headland
#  2018.0                                           La Ticla
#  2018.0                                 Flat Rock, Ballina
#  2018.0                              Piedade Beach, Recife
#  2018.0  Lighhouse Point Park, Ponce Inlet, Volusia County
#  2018.0                       Cocoa Beach, Brevard  County
#  2018.0                      Daytona Beach, Volusia County
#  2018.0                                    Cairns Aquarium
#  2018.0                  Isle of Palms,  Charleston County
#  2018.0                Hilton Head Island, Beaufort County
#  2018.0                                     Off Land's End
#  2018.0                                         Dugong Bay
#  2018.0                          Nahoon Beach, East London
#  2018.0                             Sharpes Beach, Ballina
#  2018.0                                      Sai Noi Beach
#  2018.0                                          Manuelita
#  2018.0                                       Gearys Beach
#  2018.0                                        Lennox Head
#  2018.0                            Surfers Point, Prevelly
#  2018.0                             South Point, Gracetown
#  2018.0                                          Madoogali
#  2018.0                     Robberg Beach, Plettenberg Bay
#  2018.0             Shipwrecks Beach, Keoneloa Bay, Kauai
#  2018.0                                      Sai Noi Beach
#  2018.0                                            Piedade
#  2018.0                   Lefthanders, Margaret River Area
#  2018.0                  Cobblestones, Margaret River Area
# ...                                                    ...
# NaN                                                Off Lae
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                            Symi Island
# NaN                                                    NaN
# NaN                         Spectacle Island, Port Jackson
# NaN                                              Barachois
# NaN                                               Arniston
# NaN                                                    NaN
# NaN                                                Durban
# NaN                                     Great Barrier Reef
# NaN                               Gadsden Point, Tampa Bay
# NaN                                               V?ng Tàu
# NaN                                                Durban
# NaN                                                 Durban
# NaN                                                    NaN
# NaN                Somewhere between Hatteras and Beaufort
# NaN                                                 Durban
# NaN                                                 Durban
# NaN                                                    NaN
# NaN                                                   Puna
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
# NaN
# NaN                                            Roebuck Bay
# NaN                                                    NaN
# NaN                                         Ocracoke Inlet
# NaN                                   Panama Bay 8ºN, 79ºW
# NaN                    Below the English fort, Trincomalee
#
#                                                   activity  \
# year
#  2018.0                                           Paddling
#  2018.0                                           Standing
#  2018.0                                            Surfing
#  2018.0                                            Surfing
#  2018.0                                        Free diving
#  2018.0                                       Kite surfing
#  2018.0                                           Swimming
#  2018.0                                            Fishing
#  2018.0                                            Walking
#  2018.0                                           Standing
#  2018.0                                     Feeding sharks
#  2018.0                                    Boogie boarding
#  2018.0                                           Swimming
#  2018.0                                            Fishing
#  2018.0                                     Feeding sharks
#  2018.0                                            Surfing
#  2018.0                                            Surfing
#  2018.0                                           Swimming
#  2018.0                                       Scuba diving
#  2018.0                                            Surfing
#  2018.0                                            Surfing
#  2018.0                                            Surfing
#  2018.0                                            Surfing
#  2018.0                                            Fishing
#  2018.0                                      Paddle-skiing
#  2018.0                                      Body boarding
#  2018.0                                           Swimming
#  2018.0                                           Swimming
#  2018.0                                            Surfing
#  2018.0                                            Surfing
# ...                                                    ...
# NaN           Aircraft ditched in the sea, swimming ashore
# NaN                                                Bathing
# NaN                                    Wooden fishing boat
# NaN                                          Sponge diving
# NaN                                               Standing
# NaN                                                    NaN
# NaN                                               Swimming
# NaN                                                 Wading
# NaN                                           Pearl diving
# NaN      Swimming in pool formed by construction of a w...
# NaN                                                    NaN
# NaN                                                Fishing
# NaN                          Swimming around anchored ship
# NaN            Crew swimming alongside their anchored ship
# NaN                                     4 men were bathing
# NaN                   Wreck of  large double sailing canoe
# NaN                                               Swimming
# NaN                                                Fishing
# NaN                                                 Wading
# NaN                                               Swimming
# NaN                                                    NaN
# NaN                                                Fishing
# NaN                                                Fishing
# NaN                                                Fishing
# NaN                                               Swimming
# NaN                                                 Diving
# NaN                                           Pearl diving
# NaN                                               Swimming
# NaN                                                    NaN
# NaN                                               Swimming
#
#                                   name sex_  age  \
# year
#  2018.0                    Julie Wolfe    F   57
#  2018.0                Adyson McNeely     F   11
#  2018.0                    John Denges    M   48
#  2018.0                           male    M  NaN
#  2018.0                 Gustavo Ramos     M  NaN
#  2018.0                        Chris
#     M  NaN
#  2018.0         Jose Ernesto da Silva     M   18
#  2018.0                           male    M   52
#  2018.0                      Cody High    M   15
#  2018.0                           male    M   12
#  2018.0                           male    M   32
#  2018.0                   Trey de Boer    M   10
#  2018.0                    Jei Turrell    M   10
#  2018.0                   Max Berryman    M   21
#  2018.0                Melisa Brunning    F   34
#  2018.0                           male    M  NaN
#  2018.0                           male    M  NaN
#  2018.0                         female    M  NaN
#  2018.0                           male    M   30
#  2018.0                    Adam Murray    M  NaN
#  2018.0                    Matthew Lee    M  NaN
#  2018.0                      Rob Bruce    M   60
#  2018.0                   Nathan Burch    M  NaN
#  2018.0                  Ahmed Rasheed    M   32
#  2018.0                           male    M   33
#  2018.0               Dylan McWilliams    M   29
#  2018.0               Werner Danielsen    M   54
#  2018.0                  Pablo de Melo    M   34
#  2018.0                 Jason Longrass    M   41
#  2018.0           Alejandro Travaglini    M   37
# ...                                ...  ...  ...
# NaN                               male    M  NaN
# NaN                               male    M  NaN
# NaN         Occupant:     Mr. Maciotta    M  NaN
# NaN                    Psarofa-gomenes    M  NaN
# NaN                          a servant    M   16
# NaN      male, the Sergeant of Marines    M  NaN
# NaN                                NaN  NaN  NaN
# NaN                   Madelaine Dalton    F  NaN
# NaN                        Jaringoorli    M  NaN
# NaN                         Indian boy    M  NaN
# NaN                  3 Japanese divers    M  NaN
# NaN                       James Kelley    M  NaN
# NaN                            crewman    M  NaN
# NaN                               male    M  NaN
# NaN                               male    M  NaN
# NaN                         20 Fijians  NaN  NaN
# NaN                    "youthful male"    M  NaN
# NaN                 a native fisherman    M  NaN
# NaN                   a young Scotsman    M  NaN
# NaN                         Mr. Masury    M  NaN
# NaN                       A "chiefess"    F  NaN
# NaN                                boy    M  NaN
# NaN                          fisherman    M  NaN
# NaN                          fisherman    M  NaN
# NaN                           Arab boy    M  NaN
# NaN                               male    M  NaN
# NaN                              Ahmun    M  NaN
# NaN              Coast Guard personnel    M  NaN
# NaN                    Jules Patterson    M  NaN
# NaN                               male    M   15
#
#                                                     injury fatal_yn  \
# year
#  2018.0  No injury to occupant, outrigger canoe and pad...        N
#  2018.0                         Minor injury to left thigh        N
#  2018.0       Injury to left lower leg from surfboard skeg        N
#  2018.0                          Minor injury to lower leg        N
#  2018.0  Lacerations to leg & hand shark PROVOKED INCIDENT        N
#  2018.0                            No injury, board bitten        N
#  2018.0                                              FATAL        Y
#  2018.0            Minor injury to foot. PROVOKED INCIDENT        N
#  2018.0                              Lower left leg bitten        N
#  2018.0                               Minor injury to foot        N
#  2018.0  Minor bite to hand by captive shark. PROVOKED ...        N
#  2018.0               Injuries to lower right leg and foot        N
#  2018.0                       Severe bite to right forearm        N
#  2018.0  Injured by teeth of a dead porbeagle shark he ...        N
#  2018.0    Shallow lacerations to finger PROVOKED INCIDENT        N
#  2018.0                       Minor injury, marks on board        N
#  2018.0                       No injury, surfboard damaged        N
#  2018.0                              Minor injury to ankle        N
#  2018.0                    No injury, shark bit scuba gear        N
#  2018.0              No injury, knocked off board by shark        N
#  2018.0                                          No injury        N
#  2018.0              No injury, knocked off board by shark        N
#  2018.0                    No injury, shark struck his leg        N
#  2018.0                                 5-inch cut to hand        N
#  2018.0                   No injury, shark bit hole in ski        N
#  2018.0                     Lacerations to right lower leg        N
#  2018.0                      Lacerations to foot and ankle        N
#  2018.0  Multiple severe injuries to arms and leg, leg ...      NaN
#  2018.0                          Laceration to right thigh        N
#  2018.0                                Lacerations to legs        N
# ...                                                    ...      ...
# NaN                                       Shark bumped him        N
# NaN                                              Fatal x 2        Y
# NaN             No injury to occupant; shark capsized boat        N
# NaN                                            Head bitten        N
# NaN                                                  FATAL        Y
# NaN                                                    NaN  UNKNOWN
# NaN                                                  FATAL        Y
# NaN                                           Ankle bitten        N
# NaN                                   Lacerations to thigh        N
# NaN                                    FATAL, leg severed         Y
# NaN                                                  FATAL        Y
# NaN                                     2-inch lacerations        N
# NaN                                            Foot bitten        N
# NaN                                                  FATAL        Y
# NaN                                                  FATAL        Y
# NaN      FATAL, 18 people  were killed by sharks, 2 sur...        Y
# NaN                                             "Lost leg"        N
# NaN      FATAL, body not recovered but shark was caught...        Y
# NaN                         FATAL, leg stripped of flesh          Y
# NaN                                           Foot severed        N
# NaN                                           Ankle bitten        N
# NaN      FATAL, knocked overboard by tail of shark & ca...        Y
# NaN                                                  FATAL        Y
# NaN                                                  FATAL        Y
# NaN                                                  FATAL        Y
# NaN                                                  FATAL        Y
# NaN                                                  FATAL        Y
# NaN                                                  FATAL        Y
# NaN                                                  FATAL        Y
# NaN      FATAL. "Shark bit him in half, carrying away t...        Y
#
#                    time                                           species_  \
# year
#  2018.0           18h00                                        White shark
#  2018.0   14h00  -15h00                                                NaN
#  2018.0           07h45                                                NaN
#  2018.0             NaN                                          2 m shark
#  2018.0             NaN                                    Tiger shark, 3m
#  2018.0             NaN                                                NaN
#  2018.0  Late afternoon                                        Tiger shark
#  2018.0             NaN                                    Lemon shark, 3'
#  2018.0           17h00                                     Bull shark, 6'
#  2018.0           14h00                                                NaN
#  2018.0         Morning                                    Grey reef shark
#  2018.0             NaN                                                NaN
#  2018.0           15h00                                                NaN
#  2018.0           08h15                                   Invalid incident
#  2018.0             NaN                              Tawny nurse shark, 2m
#  2018.0           11h00                                                NaN
#  2018.0           10h30                    Shark involvement not confirmed
#  2018.0             NaN                                                NaN
#  2018.0           10h40                                        Tiger shark
#  2018.0           16h50                                                NaN
#  2018.0           07h00                                       Questionable
#  2018.0           09h30                                          3 m shark
#  2018.0       Afternoon                                 White shark, 3.5 m
#  2018.0           21h50                                        Tiger shark
#  2018.0           09h40                                 White shark, 2.5 m
#  2018.0             NaN                                           6' shark
#  2018.0             NaN                                Juvenile bull shark
#  2018.0             NaN                                                NaN
#  2018.0             NaN                                                NaN
#  2018.0           08h00                                                NaN
# ...                 ...                                                ...
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                        White shark
# NaN                 NaN                                                NaN
# NaN                 NaN                                    12' tiger shark
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                       Blue pointer
# NaN                 NaN                                       Blue pointer
# NaN                 NaN                                      Blue pointers
# NaN                 NaN  Said to involve a grey nurse shark that leapt ...
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
# NaN                 NaN                                                NaN
#
#                                     investigator_or_source
# year
#  2018.0                                   R. Collier, GSAF
#  2018.0                     K.McMurray, TrackingSharks.com
#  2018.0                     K.McMurray, TrackingSharks.com
#  2018.0                                     B. Myatt, GSAF
#  2018.0                                          A .Kipper
#  2018.0                          Daily Telegraph, 6/4/2018
#  2018.0                     Diario de Pernambuco, 6/4/2018
#  2018.0                    K. McMurray, TrackingSharks.com
#  2018.0                     K.McMurray, TrackingSharks.com
#  2018.0                   K. McMurray, Tracking Sharks.com
#  2018.0                             ABC.net.au ,05/24/2018
#  2018.0                                  C. Creswell, GSAF
#  2018.0  C. Creswell, GSAF & K. McMurray TrackingSharks...
#  2018.0                    K. McMurray, TrackingSharks.com
#  2018.0                               Perth Now, 6/30/2018
#  2018.0                  B.Jacob, Dispatch Live, 5/12/2018
#  2018.0                                     B. Myatt, GSAF
#  2018.0                    K. McMurray, TrackingSharks.com
#  2018.0                         Costa Rica Star. 4/28/2018
#  2018.0                                     B. Myatt, GSAF
#  2018.0                                     B. Myatt, GSAF
#  2018.0                                      B.Myatt, GSAF
#  2018.0                                     B. Myatt, GSAF
#  2018.0                    K. McMurray, TrackingSharks.com
#  2018.0                      Africa News Agency, 4/22/2018
#  2018.0                       The Garden Island, 4/19/2018
#  2018.0                           Straits Times, 4/16/2018
#  2018.0                                   Globo, 4/16/2018
#  2018.0                                      B.Myatt, GSAF
#  2018.0                                      B.Myatt, GSAF
# ...                                                    ...
# NaN                           V.M. Coppleson (1962), p.257
# NaN                          Massillon Independent, 3/1905
# NaN                          A. De Maddalena; Anon. (1938)
# NaN                                       M. N. Kalafatas
# NaN                                        Mitchell-Hedges
# NaN                                              H. Capper
# NaN                                     G. Van Grevelynghe
# NaN                  L. Green in Tavern of the Seas, p.182
# NaN                         Adelaide Advertiser, 1/11/1940
# NaN            L. Green in South African Beachcomber, p.97
# NaN                           V.M. Coppleson (1958), p.241
# NaN                                         T. Helm, p.219
# NaN                      Daily Kennebec Journal, 3/27/1911
# NaN      Captain A. Anderson,  Natal Mercury, 12/31/192...
# NaN      Captain A. Anderson,  Natal Mercury, 12/31/192...
# NaN      Fijian Society papers presented April 17, 1918...
# NaN         C. Creswell, GSAF; Wilmington Star, 7/17/1916
# NaN                           Rural New Yorker, 7/19/1913
# NaN                            Rural New Yorker, 7/19/1913
# NaN              Ref. J. T. Dubois in N.Y. Sun, 3/19/1911
# NaN                                       Captain W. Young
# NaN      NY Sun, 9/9/1906, referring to account by Loui...
# NaN      NY Sun, 9/9/1906, referring to account by Loui...
# NaN      NY Sun, 9/9/1906, referring to account by Loui...
# NaN      L. Becke in New York Sun, 9/9/1906; L. Schultz...
# NaN                       H. Taunton; N. Bartlett,  p. 234
# NaN                  H. Taunton; N. Bartlett,  pp. 233-234
# NaN                   F. Schwartz, p.23; C. Creswell, GSAF
# NaN                                    The Sun, 10/20/1938
# NaN                                             S.W. Baker
#
# [6302 rows x 16 columns]

# %% [markdown]
# ## Clearning the right data -- and save the boat

# %%
# replace values starting from date

# %%
# function to value_counts() all the data

# %% [markdown]
# ## Index: working with dates and time series

# %%
df[df.date.notnull()].shape
# Out:
# (6296, 16)

# %%
# df.case_number.iloc[8697]

# %%
df.year.isnull().sum()
# Out:
# 127

# %%
df[df.year]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-c68baf0ccd49> in <module>
# ----> 1 df[df.year]
#
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: '[2018. 2018. 2018. ...   nan   nan   nan] not in index'

# %%
df[df.date.notnull()]
# Out:
# 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
# 5       2018.0
# 6       2018.0
# 7       2018.0
# 8       2018.0
# 9       2018.0
# 10      2018.0
# 11      2018.0
# 12      2018.0
# 13      2018.0
# 14      2018.0
# 15      2018.0
# 16      2018.0
# 17      2018.0
# 18      2018.0
# 19      2018.0
# 20      2018.0
# 21      2018.0
# 22      2018.0
# 23      2018.0
# 24      2018.0
# 25      2018.0
# 26      2018.0
# 27      2018.0
# 28      2018.0
# 29      2018.0
#          ...
# 6272       0.0
# 6273       0.0
# 6274       0.0
# 6275       0.0
# 6276       0.0
# 6277       0.0
# 6278       0.0
# 6279       0.0
# 6280       0.0
# 6281       0.0
# 6282       0.0
# 6283       0.0
# 6284       0.0
# 6285       0.0
# 6286       0.0
# 6287       0.0
# 6288       0.0
# 6289       0.0
# 6290       0.0
# 6291       0.0
# 6292       0.0
# 6293       0.0
# 6294       0.0
# 6295       0.0
# 6296       0.0
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: year, Length: 6301, dtype: float64

# %% [markdown]
# ### Examine the data for potential issues.

# %%
# clean data
df.sex_.value_counts()
# Out:
# M      5094
# F       637
# N         2
# M         2
# .         1
# lli       1
# Name: sex_, dtype: int64

# %%
# cleaning typos
df[(df.sex_=='M') | (df.sex_=='F')].sex_.value_counts()
# Out:
# M    5094
# F     637
# Name: sex_, dtype: int64

# %%
df_1.sex_.value_counts()
# Out:
# M     5094
# F      637
# N        2
# M        2
# .        1
# Name: sex_, dtype: int64

# %%
# create a referece dictionary to categorize the data
#df.species_.value_counts()

# %%
# clean and categorize the data
df.Activity.value_counts()
# Out:
# Surfing                                                                                                     971
# Swimming                                                                                                    869
# Fishing                                                                                                     431
# Spearfishing                                                                                                333
# Bathing                                                                                                     162
# Wading                                                                                                      149
# Diving                                                                                                      127
# Standing                                                                                                     99
# Snorkeling                                                                                                   89
# Scuba diving                                                                                                 76
# Body boarding                                                                                                61
# Body surfing                                                                                                 49
# Swimming                                                                                                     47
# Kayaking                                                                                                     33
# Treading water                                                                                               32
# Pearl diving                                                                                                 32
# Fell overboard                                                                                               32
# Boogie boarding                                                                                              29
# Free diving                                                                                                  29
# Windsurfing                                                                                                  19
# Walking                                                                                                      17
# Boogie Boarding                                                                                              16
# Shark fishing                                                                                                15
# Floating                                                                                                     14
# Fishing                                                                                                      13
# Canoeing                                                                                                     13
# Rowing                                                                                                       12
# Surf-skiing                                                                                                  12
# Surf skiing                                                                                                  12
# Surf fishing                                                                                                 12
#                                                                                                            ...
# Taking catch from a fish weir in which the shark was snared                                                   1
# Swimming from makeshift raft  to life vest after fishing boat sank                                            1
# Swimming 3 miles offshore                                                                                     1
# Fishing with dynamite, afterwards in water retrieving catch                                                   1
# Wading / fishing & carrying a bag of fish                                                                     1
# Cleaning hull of ship                                                                                         1
# Wreck of the 150-ton brig Maria                                                                               1
# Attempting to drag hooked shark ashore by its tail                                                            1
# Surfing, but lying prone on his board                                                                         1
# Fishing (rod & line)                                                                                          1
# Playing in the surf with his 2 dogs                                                                           1
# Free diving / spearfishing,                                                                                   1
# Fishing for trout                                                                                             1
# The 21,516-ton troopship Empress of Canada torpedoed and sunk by the Italian submarine Leonardo da Vinci      1
# Spearfishing & holding catch                                                                                  1
# Collecting beche-de-mer                                                                                       1
# Lying atop surfboard                                                                                          1
# Hiking on the beach                                                                                           1
# During "an exhibition" he was tied in sack & thrown overboard                                                 1
# Grabbed shark & threw it on deck                                                                              1
# Fell overboard from the Selim                                                                                 1
# Spearfishing, shark grabbed his white t-shirt and towed him                                                   1
# Freediving for seashells                                                                                      1
# Swimming alongside the schooner Catherine Wilcox                                                              1
# Skin diving                                                                                                   1
# Fishing, Struck by another shark when removing shark from line                                                1
# Canoe capsized with 10 occupants, 8 survived,  Hamilton swam off to seek help                                 1
# Bathing or washing                                                                                            1
# Chumming for white sharks                                                                                     1
# Plane crashed in water, men in life raft                                                                      1
# Name: Activity, Length: 1532, dtype: int64

# %%
df = df.sort_values('year')

# %%
import pandas_profiling

# %%
df.profile_report()
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="ipynb_tmp/profile_3061797223.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
