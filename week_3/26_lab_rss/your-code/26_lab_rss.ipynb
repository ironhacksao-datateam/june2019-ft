# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %% [markdown]
# * RSS stands for Rich Site Summary and uses standard web feed formats to publish frequently updated information: blog entries, news headlines, audio, video.

# %% [markdown]
# * __What is feedparser?__
#
# feedparser is a library that helps users to keep track over feeds such as RSS, and Atom in Python
# [source](https://github.com/kurtmckee/feedparser)
#
# - Documentation: https://pythonhosted.org/feedparser/

# %%
! pip install feedparser
# Out:
# Collecting feedparser
#   Using cached https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Stored in directory: /Users/liviaclarete/Library/Caches/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
# Successfully built feedparser
# Installing collected packages: feedparser
# Successfully installed feedparser-5.2.1

# %%
# import feedparser
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
# importing parse() from feedparser passing the url as an argument
feed_oreilly = feedparser.parse(url)

# %%
# feed type
type(feed_oreilly)
# Out:
# feedparser.FeedParserDict

# %%
# note the object is a dict
feed_oreilly
# Out:
# {'feed': {'title': "All - O'Reilly Media",
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': "All - O'Reilly Media"},
#   'id': 'https://www.oreilly.com',
#   'guidislink': True,
#   'link': 'https://www.oreilly.com',
#   'updated': '2019-07-20T17:51:01Z',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=20, tm_hour=17, tm_min=51, tm_sec=1, tm_wday=5, tm_yday=201, tm_isdst=0),
#   'subtitle': 'All of our Ideas and Learning material from all of our topics.',
#   'subtitle_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'All of our Ideas and Learning material from all of our topics.'},
#   'links': [{'href': 'https://www.oreilly.com',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'rel': 'self',
#     'type': 'application/atom+xml',
#     'href': 'http://feeds.feedburner.com/oreilly/radar/atom'},
#    {'rel': 'hub',
#     'href': 'http://pubsubhubbub.appspot.com/',
#     'type': 'text/html'}],
#   'authors': [{'name': "O'Reilly Media"}],
#   'author_detail': {'name': "O'Reilly Media"},
#   'author': "O'Reilly Media",
#   'feedburner_info': {'uri': 'oreilly/radar/atom'},
#   'geo_lat': '38.393314',
#   'geo_long': '-122.836667',
#   'feedburner_emailserviceid': 'oreilly/radar/atom',
#   'feedburner_feedburnerhostname': 'https://feedburner.google.com'},
#  'entries': [{'title': 'Four short links: 19 July 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 19 July 2019'},
#    'updated': '2019-07-19T17:05:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=19, tm_hour=17, tm_min=5, tm_sec=0, tm_wday=4, tm_yday=200, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-19:/ideas/four-short-links-19-july-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/JcPActoQxs0/four-short-links-19-july-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>Journal Mining, API Use, Better Conversation, and Apollo 11 Source</em></p><ol>\r\n<li>\r\n<a href="https://boingboing.net/2019/07/18/aaronsw-elbakyan-malamud.html">73 Million Journal Articles for Text Mining</a> (BoingBoing) -- <i>The JNU Data Depot is a joint project between rogue archivist Carl Malamud, bioinformatician Andrew Lynn, and a research team from New Delhi\'s Jawaharlal Nehru University: together, they have assembled 73 million journal articles from 1847 to the present day and put them into an airgapped respository that they\'re offering to noncommercial third parties who want to perform textual analysis on them to "pull out insights without actually reading the text."</i>\r\n</li>\r\n<li>\r\n<a href="http://sigdoc.acm.org/wp-content/uploads/2019/01/CDQ18002_Meng_Steinhardt_Schubert.pdf">How Developers Use API Documentation: An Observation Study</a> (ACM) -- participants totally mapped to opportunistic (risk-taking, paste-then-adapt, change-without-checking) developers and systematic (start with clean code, read the docs, learn before coding) developers.</li>\r\n<li>\r\n<a href="https://coralproject.net/talk/">Talk</a> -- <i>An open source commenting platform focused on better conversation</i>.</li>\r\n<li>\r\n<a href="https://github.com/chrislgarry/Apollo-11">Apollo 11</a> -- <i>Original Apollo 11 Guidance Computer (AGC) source code for the command and lunar modules</i>.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-19-july-2019\'>Four short links: 19 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/JcPActoQxs0" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>Journal Mining, API Use, Better Conversation, and Apollo 11 Source</em></p><ol>\r\n<li>\r\n<a href="https://boingboing.net/2019/07/18/aaronsw-elbakyan-malamud.html">73 Million Journal Articles for Text Mining</a> (BoingBoing) -- <i>The JNU Data Depot is a joint project between rogue archivist Carl Malamud, bioinformatician Andrew Lynn, and a research team from New Delhi\'s Jawaharlal Nehru University: together, they have assembled 73 million journal articles from 1847 to the present day and put them into an airgapped respository that they\'re offering to noncommercial third parties who want to perform textual analysis on them to "pull out insights without actually reading the text."</i>\r\n</li>\r\n<li>\r\n<a href="http://sigdoc.acm.org/wp-content/uploads/2019/01/CDQ18002_Meng_Steinhardt_Schubert.pdf">How Developers Use API Documentation: An Observation Study</a> (ACM) -- participants totally mapped to opportunistic (risk-taking, paste-then-adapt, change-without-checking) developers and systematic (start with clean code, read the docs, learn before coding) developers.</li>\r\n<li>\r\n<a href="https://coralproject.net/talk/">Talk</a> -- <i>An open source commenting platform focused on better conversation</i>.</li>\r\n<li>\r\n<a href="https://github.com/chrislgarry/Apollo-11">Apollo 11</a> -- <i>Original Apollo 11 Guidance Computer (AGC) source code for the command and lunar modules</i>.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-19-july-2019\'>Four short links: 19 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/JcPActoQxs0" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/JcPActoQxs0/four-short-links-19-july-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-19-july-2019'},
#   {'title': 'The war for the soul of open source',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The war for the soul of open source'},
#    'updated': '2019-07-18T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=18, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=199, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-18:/ideas/the-war-for-the-soul-of-open-source',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9O3JPPF9Ac0/the-war-for-the-soul-of-open-source',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-open-source-soul-crop-b8aa5b798851faf3ed18fde661c206b9.jpg\'/></p><p><em>Drawing on 13 years spent building the Chef community, Adam Jacob takes a deep dive into the soul of open source.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/the-war-for-the-soul-of-open-source\'>The war for the soul of open source.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/9O3JPPF9Ac0" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-open-source-soul-crop-b8aa5b798851faf3ed18fde661c206b9.jpg\'/></p><p><em>Drawing on 13 years spent building the Chef community, Adam Jacob takes a deep dive into the soul of open source.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/the-war-for-the-soul-of-open-source\'>The war for the soul of open source.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/9O3JPPF9Ac0" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9O3JPPF9Ac0/the-war-for-the-soul-of-open-source',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Adam Jacob'}],
#    'author_detail': {'name': 'Adam Jacob'},
#    'author': 'Adam Jacob',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/the-war-for-the-soul-of-open-source'},
#   {'title': 'Ask not what Brands™ can do for you',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Ask not what Brands™ can do for you'},
#    'updated': '2019-07-18T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=18, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=199, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-18:/ideas/ask-not-what-brands-can-do-for-you',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/gbaXqNZfl2s/ask-not-what-brands-can-do-for-you',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-scaffolding-crop-5e48467b609f64b4b9f9fb9cdcd21f5e.jpg\'/></p><p><em>VM Brasseur discusses the help new companies need to become authentic members of the free and open source software community.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/ask-not-what-brands-can-do-for-you\'>Ask not what Brands™ can do for you.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/gbaXqNZfl2s" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-scaffolding-crop-5e48467b609f64b4b9f9fb9cdcd21f5e.jpg\'/></p><p><em>VM Brasseur discusses the help new companies need to become authentic members of the free and open source software community.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/ask-not-what-brands-can-do-for-you\'>Ask not what Brands™ can do for you.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/gbaXqNZfl2s" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/gbaXqNZfl2s/ask-not-what-brands-can-do-for-you',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'VM Brasseur'}],
#    'author_detail': {'name': 'VM Brasseur'},
#    'author': 'VM Brasseur',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/ask-not-what-brands-can-do-for-you'},
#   {'title': 'O’Reilly Radar: Open source technology trends—What our users tell us',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'O’Reilly Radar: Open source technology trends—What our users tell us'},
#    'updated': '2019-07-18T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=18, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=199, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-18:/ideas/oreilly-radar-open-source-technology-trends-oscon-19',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4bugL3UnKgE/oreilly-radar-open-source-technology-trends-oscon-19',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-radar-tool-trends-crop-82e91b9b504451e1698239a6f61e21fb.jpg\'/></p><p><em>Using aggregate analysis of O’Reilly online learning content usage and search data, Roger Magoulas shares key insights that impact the technology tools ecosystem.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/oreilly-radar-open-source-technology-trends-oscon-19\'>O’Reilly Radar: Open source technology trends—What our users tell us.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/4bugL3UnKgE" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-radar-tool-trends-crop-82e91b9b504451e1698239a6f61e21fb.jpg\'/></p><p><em>Using aggregate analysis of O’Reilly online learning content usage and search data, Roger Magoulas shares key insights that impact the technology tools ecosystem.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/oreilly-radar-open-source-technology-trends-oscon-19\'>O’Reilly Radar: Open source technology trends—What our users tell us.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/4bugL3UnKgE" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4bugL3UnKgE/oreilly-radar-open-source-technology-trends-oscon-19',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Roger Magoulas'}],
#    'author_detail': {'name': 'Roger Magoulas'},
#    'author': 'Roger Magoulas',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/oreilly-radar-open-source-technology-trends-oscon-19'},
#   {'title': "O'Reilly Open Source and Frank Willison Awards",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': "O'Reilly Open Source and Frank Willison Awards"},
#    'updated': '2019-07-18T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=18, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=199, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-18:/ideas/oreilly-open-source-and-frank-willison-awards-19',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/B0irnzvZ3j0/oreilly-open-source-and-frank-willison-awards-19',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-open-source-awards-crop-9443a391a852e34d4585b02778f39a9a.jpg\'/></p><p><em>The O’Reilly Open Source Awards recognize individual contributors who have demonstrated exceptional leadership, creativity, and collaboration in the development of open source software.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/oreilly-open-source-and-frank-willison-awards-19\'>O\'Reilly Open Source and Frank Willison Awards.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/B0irnzvZ3j0" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-open-source-awards-crop-9443a391a852e34d4585b02778f39a9a.jpg\'/></p><p><em>The O’Reilly Open Source Awards recognize individual contributors who have demonstrated exceptional leadership, creativity, and collaboration in the development of open source software.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/oreilly-open-source-and-frank-willison-awards-19\'>O\'Reilly Open Source and Frank Willison Awards.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/B0irnzvZ3j0" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/B0irnzvZ3j0/oreilly-open-source-and-frank-willison-awards-19',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/oreilly-open-source-and-frank-willison-awards-19'},
#   {'title': 'Managing machines',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Managing machines'},
#    'updated': '2019-07-18T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=18, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=199, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-18:/ideas/managing-machines',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/jQTe46_xLnU/managing-machines',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-managing-machines-crop-856bfad6570ec54ee49112645f128d4e.jpg\'/></p><p><em>Pete Skomoroch covers what you need to know as we shift from a world of deterministic programs to systems that give unpredictable results on ever-changing training data.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/managing-machines\'>Managing machines.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/jQTe46_xLnU" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-managing-machines-crop-856bfad6570ec54ee49112645f128d4e.jpg\'/></p><p><em>Pete Skomoroch covers what you need to know as we shift from a world of deterministic programs to systems that give unpredictable results on ever-changing training data.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/managing-machines\'>Managing machines.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/jQTe46_xLnU" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/jQTe46_xLnU/managing-machines',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Pete Skomoroch'}],
#    'author_detail': {'name': 'Pete Skomoroch'},
#    'author': 'Pete Skomoroch',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/managing-machines'},
#   {'title': 'Acquiring and sharing high-quality data',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Acquiring and sharing high-quality data'},
#    'updated': '2019-07-18T13:30:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=18, tm_hour=13, tm_min=30, tm_sec=0, tm_wday=3, tm_yday=199, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-18:/ideas/acquiring-and-sharing-high-quality-data',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/hu0E6GMGrk4/acquiring-and-sharing-high-quality-data',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/ny_stock_exchange_traders_floor_lc-u9-10548-6_crop-eabe7c1ba98335b73de482edab431af4.jpg\'/></p><p><em>The O’Reilly Data Show Podcast: Roger Chen on the fair value and decentralized governance of data.</em></p><p>In this episode of the <a href="https://www.oreilly.com/ideas/topics/oreilly-data-show-podcast">Data Show</a>, I spoke with Roger Chen, co-founder and CEO of <a href="https://www.computable.io/">Computable Labs</a>, a startup focused on building tools for the creation of data networks and data exchanges. Chen has also served as co-chair of <a href="http://theaiconf.com">O\'Reilly\'s Artificial Intelligence Conference</a> since its inception in 2016. This conversation took place the day after Chen and his collaborators <a href="https://medium.com/computable-blog/computable-whitepaper-a-fair-market-protocol-for-data-f56f0b4143f8">released</a> an interesting new white paper, <a href="https://github.com/computablelabs/computable/blob/master/whitepaper/computable_whitepaper.pdf"><em>Fair value and decentralized governance of data</em></a>. Current-generation AI and machine learning technologies rely on large amounts of data, and to the extent they can use their large user bases to create “data silos,” large companies in large countries (like the U.S. and China) enjoy a competitive advantage. With that said, we are awash in articles about the dangers posed by these data silos. Privacy and security, disinformation, bias, and a <a href="https://www.oreilly.com/ideas/the-importance-of-transparency-and-user-control-in-machine-learning">lack of transparency and control</a> are just some of the issues that have plagued the perceived owners of “data monopolies.”</p>\r\n\r\n<p>In recent years, researchers and practitioners have begun building tools focused on helping organizations acquire, build, and share high-quality data. Chen and his collaborators are doing some of the most interesting work in this space, and I recommend their <a href="https://github.com/computablelabs/computable/blob/master/whitepaper/computable_whitepaper.pdf">new white paper</a> and accompanying <a href="https://github.com/computablelabs">open source projects</a>.</p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/acquiring-and-sharing-high-quality-data\'>Acquiring and sharing high-quality data.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/hu0E6GMGrk4" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/ny_stock_exchange_traders_floor_lc-u9-10548-6_crop-eabe7c1ba98335b73de482edab431af4.jpg\'/></p><p><em>The O’Reilly Data Show Podcast: Roger Chen on the fair value and decentralized governance of data.</em></p><p>In this episode of the <a href="https://www.oreilly.com/ideas/topics/oreilly-data-show-podcast">Data Show</a>, I spoke with Roger Chen, co-founder and CEO of <a href="https://www.computable.io/">Computable Labs</a>, a startup focused on building tools for the creation of data networks and data exchanges. Chen has also served as co-chair of <a href="http://theaiconf.com">O\'Reilly\'s Artificial Intelligence Conference</a> since its inception in 2016. This conversation took place the day after Chen and his collaborators <a href="https://medium.com/computable-blog/computable-whitepaper-a-fair-market-protocol-for-data-f56f0b4143f8">released</a> an interesting new white paper, <a href="https://github.com/computablelabs/computable/blob/master/whitepaper/computable_whitepaper.pdf"><em>Fair value and decentralized governance of data</em></a>. Current-generation AI and machine learning technologies rely on large amounts of data, and to the extent they can use their large user bases to create “data silos,” large companies in large countries (like the U.S. and China) enjoy a competitive advantage. With that said, we are awash in articles about the dangers posed by these data silos. Privacy and security, disinformation, bias, and a <a href="https://www.oreilly.com/ideas/the-importance-of-transparency-and-user-control-in-machine-learning">lack of transparency and control</a> are just some of the issues that have plagued the perceived owners of “data monopolies.”</p>\r\n\r\n<p>In recent years, researchers and practitioners have begun building tools focused on helping organizations acquire, build, and share high-quality data. Chen and his collaborators are doing some of the most interesting work in this space, and I recommend their <a href="https://github.com/computablelabs/computable/blob/master/whitepaper/computable_whitepaper.pdf">new white paper</a> and accompanying <a href="https://github.com/computablelabs">open source projects</a>.</p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/acquiring-and-sharing-high-quality-data\'>Acquiring and sharing high-quality data.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/hu0E6GMGrk4" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/hu0E6GMGrk4/acquiring-and-sharing-high-quality-data',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Ben Lorica'}],
#    'author_detail': {'name': 'Ben Lorica'},
#    'author': 'Ben Lorica',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/acquiring-and-sharing-high-quality-data'},
#   {'title': 'Four short links: 18 July 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 18 July 2019'},
#    'updated': '2019-07-18T08:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=18, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=199, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-18:/ideas/four-short-links-18-july-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/eFQP6NgFzkU/four-short-links-18-july-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>Weird Algorithms, Open Syllabi, Conversational AI, and Quantum Computing</em></p><ol>\r\n\t<li>\r\n<a href="https://www.youtube.com/watch?v=DpXy041BIlA">30 Weird Chess Algorithms</a> (YouTube) — <i>An intricate and lengthy account of several different computer chess topics from my SIGBOVIK 2019 papers. We conduct a tournament of fools with a pile of different weird chess algorithms, ostensibly to quantify how well my other weird program to play color- and piece-blind chess performs. On the way we "learn" about mirrors, arithmetic encoding, perversions of game tree search, spicy oils, and hats.</i>\r\n</li>\r\n\t<li>\r\n<a href="https://opensyllabus.org/">Open Syllabus Project</a> — as <a href="https://www.fastcompany.com/90376685/this-historic-map-of-6-million-syllabi-reveals-how-college-is-changing">FastCompany explains</a>, the 6M+ syllabi from courses around the world tell us about changing trends in subjects. Not sure how I feel that four of the textbooks I learned on are still in the top 20 (Cormen, Tanenbaum, Silberschatz, Stallings).</li>\r\n\t<li>\r\n<a href="https://github.com/uber-research/plato-research-dialogue-system">Plato</a> — Uber open-sourced its <i>flexible platform for developing conversational AI agents.</i> See also <a href="https://eng.uber.com/plato-research-dialogue-system/">their blog post</a>.</li>\r\n\t<li>\r\n<a href="https://www.sciencedaily.com/releases/2019/07/190717132757.htm">Speediest Quantum Operation Yet</a> (ScienceDaily) — <i>In Professor Michelle Simmons\' approach, quantum bits (or qubits) are made from electrons hosted on phosphorus atoms in silicon.[...] "Atom qubits hold the world record for the longest coherence times of a qubit in silicon with the highest fidelities," she says. "Using our unique fabrication technologies, we have already demonstrated the ability to read and initialise single electron spins on atom qubits in silicon with very high accuracy. We\'ve also demonstrated that our atomic-scale circuitry has the lowest electrical noise of any system yet devised to connect to a semiconductor qubit." [...] A two-qubit gate is the central building block of any quantum computer -- and the UNSW team\'s version of it is the fastest that\'s ever been demonstrated in silicon, completing an operation in 0.8 nanoseconds, which is ~200 times faster than other existing spin-based two-qubit gates.</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-18-july-2019\'>Four short links: 18 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/eFQP6NgFzkU" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>Weird Algorithms, Open Syllabi, Conversational AI, and Quantum Computing</em></p><ol>\r\n\t<li>\r\n<a href="https://www.youtube.com/watch?v=DpXy041BIlA">30 Weird Chess Algorithms</a> (YouTube) — <i>An intricate and lengthy account of several different computer chess topics from my SIGBOVIK 2019 papers. We conduct a tournament of fools with a pile of different weird chess algorithms, ostensibly to quantify how well my other weird program to play color- and piece-blind chess performs. On the way we "learn" about mirrors, arithmetic encoding, perversions of game tree search, spicy oils, and hats.</i>\r\n</li>\r\n\t<li>\r\n<a href="https://opensyllabus.org/">Open Syllabus Project</a> — as <a href="https://www.fastcompany.com/90376685/this-historic-map-of-6-million-syllabi-reveals-how-college-is-changing">FastCompany explains</a>, the 6M+ syllabi from courses around the world tell us about changing trends in subjects. Not sure how I feel that four of the textbooks I learned on are still in the top 20 (Cormen, Tanenbaum, Silberschatz, Stallings).</li>\r\n\t<li>\r\n<a href="https://github.com/uber-research/plato-research-dialogue-system">Plato</a> — Uber open-sourced its <i>flexible platform for developing conversational AI agents.</i> See also <a href="https://eng.uber.com/plato-research-dialogue-system/">their blog post</a>.</li>\r\n\t<li>\r\n<a href="https://www.sciencedaily.com/releases/2019/07/190717132757.htm">Speediest Quantum Operation Yet</a> (ScienceDaily) — <i>In Professor Michelle Simmons\' approach, quantum bits (or qubits) are made from electrons hosted on phosphorus atoms in silicon.[...] "Atom qubits hold the world record for the longest coherence times of a qubit in silicon with the highest fidelities," she says. "Using our unique fabrication technologies, we have already demonstrated the ability to read and initialise single electron spins on atom qubits in silicon with very high accuracy. We\'ve also demonstrated that our atomic-scale circuitry has the lowest electrical noise of any system yet devised to connect to a semiconductor qubit." [...] A two-qubit gate is the central building block of any quantum computer -- and the UNSW team\'s version of it is the fastest that\'s ever been demonstrated in silicon, completing an operation in 0.8 nanoseconds, which is ~200 times faster than other existing spin-based two-qubit gates.</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-18-july-2019\'>Four short links: 18 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/eFQP6NgFzkU" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/eFQP6NgFzkU/four-short-links-18-july-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-18-july-2019'},
#   {'title': 'Better living through software',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Better living through software'},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/better-living-through-software',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HhKaIL6C2Ow/better-living-through-software',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-sunset-over-water-with-tree-crop-7d0618c0744d00a00b83dd77ed7ef658.jpg\'/></p><p><em>Tiffani Bell shares three lessons she\'s learned exploring how technology can help the less fortunate.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/better-living-through-software\'>Better living through software.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/HhKaIL6C2Ow" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-sunset-over-water-with-tree-crop-7d0618c0744d00a00b83dd77ed7ef658.jpg\'/></p><p><em>Tiffani Bell shares three lessons she\'s learned exploring how technology can help the less fortunate.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/better-living-through-software\'>Better living through software.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/HhKaIL6C2Ow" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HhKaIL6C2Ow/better-living-through-software',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Tiffani Bell'}],
#    'author_detail': {'name': 'Tiffani Bell'},
#    'author': 'Tiffani Bell',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/better-living-through-software'},
#   {'title': 'Built to last: Building and growing open source communities',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Built to last: Building and growing open source communities'},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/built-to-last-building-and-growing-open-source-communities',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/-4Lg-QA_OcY/built-to-last-building-and-growing-open-source-communities',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-built-to-last-crop-3ce1c2094460dcc3fe1156cb818db238.jpg\'/></p><p><em>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities\'>Built to last: Building and growing open source communities.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/-4Lg-QA_OcY" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-built-to-last-crop-3ce1c2094460dcc3fe1156cb818db238.jpg\'/></p><p><em>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities\'>Built to last: Building and growing open source communities.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/-4Lg-QA_OcY" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/-4Lg-QA_OcY/built-to-last-building-and-growing-open-source-communities',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Kay Williams'}],
#    'author_detail': {'name': 'Kay Williams'},
#    'author': 'Kay Williams',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities'},
#   {'title': 'The next age of open innovation',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The next age of open innovation'},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/the-next-age-of-open-innovation',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/em9fjabzUqE/the-next-age-of-open-innovation',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-open-innovation-crop-3aeb778e11eddd535b476c02ea4d0f7b.jpg\'/></p><p><em>Alison McCauley looks at how blockchain technology offers new tools that can help extend the ethos of open innovation into new areas.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/the-next-age-of-open-innovation\'>The next age of open innovation.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/em9fjabzUqE" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-open-innovation-crop-3aeb778e11eddd535b476c02ea4d0f7b.jpg\'/></p><p><em>Alison McCauley looks at how blockchain technology offers new tools that can help extend the ethos of open innovation into new areas.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/the-next-age-of-open-innovation\'>The next age of open innovation.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/em9fjabzUqE" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/em9fjabzUqE/the-next-age-of-open-innovation',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Alison McCauley'}],
#    'author_detail': {'name': 'Alison McCauley'},
#    'author': 'Alison McCauley',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/the-next-age-of-open-innovation'},
#   {'title': "Highlights from the O'Reilly Open Source Software Conference in Portland 2019",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': "Highlights from the O'Reilly Open Source Software Conference in Portland 2019"},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/highlights-from-oscon-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/TwO4VtSQLjo/highlights-from-oscon-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/hero-h-1400x950-34c6325967a4c3cf52ca414fbe91f069.jpg\'/></p><p><em>Experts explore the role open source software plays in fields as varied as machine learning, blockchain, disaster response, and more.</em></p><p>People from across the open source world came together in Portland, Ore. for the <a href="https://conferences.oreilly.com/oscon/oscon-or">O\'Reilly Open Source Software Conference (OSCON)</a>. Below you\'ll find links to highlights from the event.</p>\n\n\n<h2>The war for the soul of open source</h2>\n\n<p>Drawing on 13 years spent building the Chef community, Adam Jacob takes a deep dive into the soul of open source.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-war-for-the-soul-of-open-source">The war for the soul of open source</a>"</li>\n</ul>\n\n<h2>Ask not what Brands™ can do for you</h2>\n\n<p>VM Brasseur discusses the help new companies need to become authentic members of the free and open source software community.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/ask-not-what-brands-can-do-for-you">Ask not what Brands™ can do for you</a>"</li>\n</ul>\n\n<h2>Better living through software</h2>\n\n<p>Tiffani Bell shares three lessons she\'s learned exploring how technology can help the less fortunate.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/better-living-through-software">Better living through software</a>"</li>\n</ul>\n\n<h2>O’Reilly Radar: Open source technology trends—What our users tell us</h2>\n\n<p>Using aggregate analysis of O’Reilly online learning content usage and search data, Roger Magoulas shares key insights that impact the technology tools ecosystem.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/oreilly-radar-open-source-technology-trends-oscon-19">O’Reilly Radar: Open source technology trends—What our users tell us</a>"</li>\n</ul>\n\n\n<h2>The next age of open innovation</h2>\n\n<p>Alison McCauley looks at how blockchain technology offers new tools that can help extend the ethos of open innovation into new areas.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-next-age-of-open-innovation">The next age of open innovation</a>"</li>\n</ul>\n\n<h2>Managing machines</h2>\n\n<p>Pete Skomoroch covers what you need to know as we shift from a world of deterministic programs to systems that give unpredictable results on ever-changing training data.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/managing-machines">Managing machines</a>"</li>\n</ul>\n\n<h2>Built to last: Building and growing open source communities</h2>\n\n<p>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities">Built to last: Building and growing open source communities</a>"</li>\n</ul>\n\n\n<h2>The role of open source in mitigating natural disasters</h2>\n\n<p>Pedro Cruz and Brad Topol discuss Call for Code, a global developer competition that uses open source technologies to address natural disasters.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters">The role of open source in mitigating natural disasters</a>"</li>\n</ul>\n\n<h2>Why Amazon cares about open source</h2>\n\n<p>Arun Gupta discusses the reasons why AWS is committed to open projects and communities.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/why-amazon-cares-about-open-source">Why Amazon cares about open source</a>"</li>\n</ul>\n\n<h2>O\'Reilly Open Source and Frank Willison Awards</h2>\n\n<p>The O’Reilly Open Source Awards recognize individual contributors who have demonstrated exceptional leadership, creativity, and collaboration in the development of open source software. < ...
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/hero-h-1400x950-34c6325967a4c3cf52ca414fbe91f069.jpg\'/></p><p><em>Experts explore the role open source software plays in fields as varied as machine learning, blockchain, disaster response, and more.</em></p><p>People from across the open source world came together in Portland, Ore. for the <a href="https://conferences.oreilly.com/oscon/oscon-or">O\'Reilly Open Source Software Conference (OSCON)</a>. Below you\'ll find links to highlights from the event.</p>\n\n\n<h2>The war for the soul of open source</h2>\n\n<p>Drawing on 13 years spent building the Chef community, Adam Jacob takes a deep dive into the soul of open source.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-war-for-the-soul-of-open-source">The war for the soul of open source</a>"</li>\n</ul>\n\n<h2>Ask not what Brands™ can do for you</h2>\n\n<p>VM Brasseur discusses the help new companies need to become authentic members of the free and open source software community.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/ask-not-what-brands-can-do-for-you">Ask not what Brands™ can do for you</a>"</li>\n</ul>\n\n<h2>Better living through software</h2>\n\n<p>Tiffani Bell shares three lessons she\'s learned exploring how technology can help the less fortunate.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/better-living-through-software">Better living through software</a>"</li>\n</ul>\n\n<h2>O’Reilly Radar: Open source technology trends—What our users tell us</h2>\n\n<p>Using aggregate analysis of O’Reilly online learning content usage and search data, Roger Magoulas shares key insights that impact the technology tools ecosystem.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/oreilly-radar-open-source-technology-trends-oscon-19">O’Reilly Radar: Open source technology trends—What our users tell us</a>"</li>\n</ul>\n\n\n<h2>The next age of open innovation</h2>\n\n<p>Alison McCauley looks at how blockchain technology offers new tools that can help extend the ethos of open innovation into new areas.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-next-age-of-open-innovation">The next age of open innovation</a>"</li>\n</ul>\n\n<h2>Managing machines</h2>\n\n<p>Pete Skomoroch covers what you need to know as we shift from a world of deterministic programs to systems that give unpredictable results on ever-changing training data.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/managing-machines">Managing machines</a>"</li>\n</ul>\n\n<h2>Built to last: Building and growing open source communities</h2>\n\n<p>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities">Built to last: Building and growing open source communities</a>"</li>\n</ul>\n\n\n<h2>The role of open source in mitigating natural disasters</h2>\n\n<p>Pedro Cruz and Brad Topol discuss Call for Code, a global developer competition that uses open source technologies to address natural disasters.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters">The role of open source in mitigating natural disasters</a>"</li>\n</ul>\n\n<h2>Why Amazon cares about open source</h2>\n\n<p>Arun Gupta discusses the reasons why AWS is committed to open projects and communities.</p>\n\n<ul>\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/why-amazon-cares-about-open-source">Why Amazon cares about open source</a>"</li>\n</ul>\n\n<h2>O\'Reilly Open Source and Frank Willison Awards</h2>\n\n<p>The O’Reilly Open Source Awards recognize individual contributors who have demonstrated exceptional leadership, creativity, and collaboration in the development of open source software. < ...
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/TwO4VtSQLjo/highlights-from-oscon-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Mac Slocum'}],
#    'author_detail': {'name': 'Mac Slocum'},
#    'author': 'Mac Slocum',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/highlights-from-oscon-2019'},
#   {'title': 'The role of open source in mitigating natural disasters',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The role of open source in mitigating natural disasters'},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/the-role-of-open-source-in-mitigating-natural-disasters',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DN0K0LdDME8/the-role-of-open-source-in-mitigating-natural-disasters',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-os-natural-disaster-crop-e4d65518ed0ed9eb259d6e1c2a04af95.jpg\'/></p><p><em>Pedro Cruz and Brad Topol discuss Call for Code, a global developer competition that uses open source technologies to address natural disasters.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters\'>The role of open source in mitigating natural disasters.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/DN0K0LdDME8" height="1" width="1" alt=""/>'}],
# ...
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ydmkFcI6ZXU/four-short-links-17-june-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-17-june-2019'},
#   {'title': 'Prioritizing technical debt as if time and money mattered',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Prioritizing technical debt as if time and money mattered'},
#    'updated': '2019-06-14T21:30:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=14, tm_hour=21, tm_min=30, tm_sec=0, tm_wday=4, tm_yday=165, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-06-14:/ideas/prioritizing-technical-debt-as-if-time-and-money-mattered',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/T401qlUwAug/prioritizing-technical-debt-as-if-time-and-money-mattered',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/5880260_8b87ab22_original_crop-405912354644707bef17cb38d5cc5ee7.jpg\'/></p><p><em>Adam Tornhill offers a new perspective on software development that will change how you view code.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/prioritizing-technical-debt-as-if-time-and-money-mattered\'>Prioritizing technical debt as if time and money mattered.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/T401qlUwAug" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/5880260_8b87ab22_original_crop-405912354644707bef17cb38d5cc5ee7.jpg\'/></p><p><em>Adam Tornhill offers a new perspective on software development that will change how you view code.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/prioritizing-technical-debt-as-if-time-and-money-mattered\'>Prioritizing technical debt as if time and money mattered.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/T401qlUwAug" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/T401qlUwAug/prioritizing-technical-debt-as-if-time-and-money-mattered',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Adam Tornhill'}],
#    'author_detail': {'name': 'Adam Tornhill'},
#    'author': 'Adam Tornhill',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/prioritizing-technical-debt-as-if-time-and-money-mattered'},
#   {'title': 'From the trenches with Rebecca Parsons',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'From the trenches with Rebecca Parsons'},
#    'updated': '2019-06-14T21:30:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=14, tm_hour=21, tm_min=30, tm_sec=0, tm_wday=4, tm_yday=165, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-06-14:/ideas/from-the-trenches-with-rebecca-parsons',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/FWMibe_uCEI/from-the-trenches-with-rebecca-parsons',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/watch-car-wheel-view-lookout-telescope-919894-pxhere_crop-f4d9369ede6819e8b03e1128a1d9ae7b.jpg\'/></p><p><em>Rebecca Parsons shares the story of her career path and her work as an architect.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/from-the-trenches-with-rebecca-parsons\'>From the trenches with Rebecca Parsons.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/FWMibe_uCEI" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/watch-car-wheel-view-lookout-telescope-919894-pxhere_crop-f4d9369ede6819e8b03e1128a1d9ae7b.jpg\'/></p><p><em>Rebecca Parsons shares the story of her career path and her work as an architect.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/from-the-trenches-with-rebecca-parsons\'>From the trenches with Rebecca Parsons.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/FWMibe_uCEI" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/FWMibe_uCEI/from-the-trenches-with-rebecca-parsons',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Rebecca Parsons, Neal Ford'}],
#    'author_detail': {'name': 'Rebecca Parsons, Neal Ford'},
#    'author': 'Rebecca Parsons, Neal Ford',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/from-the-trenches-with-rebecca-parsons'},
#   {'title': 'Choices of scale',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Choices of scale'},
#    'updated': '2019-06-14T21:30:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=14, tm_hour=21, tm_min=30, tm_sec=0, tm_wday=4, tm_yday=165, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-06-14:/ideas/choices-of-scale',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0zhNIASlMLk/choices-of-scale',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/building-1834709_1920_crop-dd07a24fddb14e1850bfb6eb2522a76d.jpg\'/></p><p><em>Michael Feathers explores various scaling strategies in light of research about human cognition and systems cohesion.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/choices-of-scale\'>Choices of scale.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/0zhNIASlMLk" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/building-1834709_1920_crop-dd07a24fddb14e1850bfb6eb2522a76d.jpg\'/></p><p><em>Michael Feathers explores various scaling strategies in light of research about human cognition and systems cohesion.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/choices-of-scale\'>Choices of scale.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/0zhNIASlMLk" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0zhNIASlMLk/choices-of-scale',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Michael Feathers'}],
#    'author_detail': {'name': 'Michael Feathers'},
#    'author': 'Michael Feathers',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/choices-of-scale'},
#   {'title': 'Four short links: 14 June 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 14 June 2019'},
#    'updated': '2019-06-14T11:10:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=14, tm_hour=11, tm_min=10, tm_sec=0, tm_wday=4, tm_yday=165, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-06-14:/ideas/four-short-links-14-june-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/pn-f97MpJ3w/four-short-links-14-june-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>Information Operations, Game Creator, History Lessons, and Physical Pen Testing</em></p><ol>\r\n<li>\r\n<a href="https://blog.twitter.com/en_us/topics/company/2019/information-ops-on-twitter.html">Information Operations on Twitter: Principles, Process, and Disclosure</a> (Twitter) -- <i>We believe that people and organizations with the advantages of institutional power and which consciously abuse our service are not advancing healthy discourse but are actively working to undermine it. By making this data open and accessible, we seek to empower researchers, journalists, governments, and members of the public to deepen their understanding of critical issues impacting the integrity of public conversation online, particularly around elections. This transparency is core to our mission.</i> Twitter is leading in this area; it\'s great to see. I hope this makes others lift their game.</li>\r\n<li>\r\n<a href="https://www.blog.google/technology/area-120/create-3d-games-friends-no-experience-required/">Create 3D Games with Friends, No Experience Required</a> (Google) -- <i>Our prototype is called Game Builder, and it is free on Steam for PC and Mac.</i>\r\n</li>\r\n<li>\r\n<a href="https://www.collaborativefund.com/blog/five-lessons-from-history/">Five Lessons from History</a> -- all are relevant to business as well as to wider politics: <i>People suffering from sudden, unexpected hardship are likely to adopt views they previously thought unthinkable. Reversion to the mean occurs because people persuasive enough to make something grow don’t have the kind of personalities that allow them to stop before pushing too far. Unsustainable things can last longer than you anticipate.  Progress happens too slowly for people to notice; setbacks happen too fast for people to ignore. Wounds heal; scars last.</i>\r\n</li>\r\n<li>\r\n<a href="https://www.youtube.com/watch?v=rnmcRTnTNC8">I\'ll Let Myself In: Tactics of Physical Pen Testers</a> (YouTube) -- <i>As head of a Physical Penetration team, however, my deliverable day tends to be quite different. With faces agog, executives routinely watch me describe (or show video) of their doors and cabinets popping open in seconds. This presentation will highlight some of the most exciting and shocking methods by which my team and I routinely let ourselves in on physical jobs.</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-14-june-2019\'>Four short links: 14 June 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/pn-f97MpJ3w" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>Information Operations, Game Creator, History Lessons, and Physical Pen Testing</em></p><ol>\r\n<li>\r\n<a href="https://blog.twitter.com/en_us/topics/company/2019/information-ops-on-twitter.html">Information Operations on Twitter: Principles, Process, and Disclosure</a> (Twitter) -- <i>We believe that people and organizations with the advantages of institutional power and which consciously abuse our service are not advancing healthy discourse but are actively working to undermine it. By making this data open and accessible, we seek to empower researchers, journalists, governments, and members of the public to deepen their understanding of critical issues impacting the integrity of public conversation online, particularly around elections. This transparency is core to our mission.</i> Twitter is leading in this area; it\'s great to see. I hope this makes others lift their game.</li>\r\n<li>\r\n<a href="https://www.blog.google/technology/area-120/create-3d-games-friends-no-experience-required/">Create 3D Games with Friends, No Experience Required</a> (Google) -- <i>Our prototype is called Game Builder, and it is free on Steam for PC and Mac.</i>\r\n</li>\r\n<li>\r\n<a href="https://www.collaborativefund.com/blog/five-lessons-from-history/">Five Lessons from History</a> -- all are relevant to business as well as to wider politics: <i>People suffering from sudden, unexpected hardship are likely to adopt views they previously thought unthinkable. Reversion to the mean occurs because people persuasive enough to make something grow don’t have the kind of personalities that allow them to stop before pushing too far. Unsustainable things can last longer than you anticipate.  Progress happens too slowly for people to notice; setbacks happen too fast for people to ignore. Wounds heal; scars last.</i>\r\n</li>\r\n<li>\r\n<a href="https://www.youtube.com/watch?v=rnmcRTnTNC8">I\'ll Let Myself In: Tactics of Physical Pen Testers</a> (YouTube) -- <i>As head of a Physical Penetration team, however, my deliverable day tends to be quite different. With faces agog, executives routinely watch me describe (or show video) of their doors and cabinets popping open in seconds. This presentation will highlight some of the most exciting and shocking methods by which my team and I routinely let ourselves in on physical jobs.</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-14-june-2019\'>Four short links: 14 June 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/pn-f97MpJ3w" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/pn-f97MpJ3w/four-short-links-14-june-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-14-june-2019'}],
#  'bozo': 0,
#  'headers': {'Content-Type': 'text/xml; charset=UTF-8',
#   'ETag': '8opgjGvqSn2pYMTgKpA91oFNGJs',
#   'Last-Modified': 'Sat, 20 Jul 2019 17:52:19 GMT',
#   'Content-Encoding': 'gzip',
#   'Transfer-Encoding': 'chunked',
#   'Date': 'Sat, 20 Jul 2019 17:57:25 GMT',
#   'Expires': 'Sat, 20 Jul 2019 17:57:25 GMT',
#   'Cache-Control': 'private, max-age=0',
#   'X-Content-Type-Options': 'nosniff',
#   'X-XSS-Protection': '1; mode=block',
#   'Server': 'GSE',
#   'Connection': 'close'},
#  'etag': '8opgjGvqSn2pYMTgKpA91oFNGJs',
#  'updated': 'Sat, 20 Jul 2019 17:52:19 GMT',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=20, tm_hour=17, tm_min=52, tm_sec=19, tm_wday=5, tm_yday=201, tm_isdst=0),
#  'href': 'http://feeds.feedburner.com/oreilly/radar/atom',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'atom10',
#  'namespaces': {'': 'http://www.w3.org/2005/Atom',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'feedburner': 'http://rssnamespace.org/feedburner/ext/1.0'}}

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
# we can access the keys elements by calling keys() over the the 
keys = list(feed_oreilly.keys())

# %%
len(keys)
# Out:
# 12

# %%
# 12 keys are listed
keys
# Out:
# ['feed',
#  'entries',
#  'bozo',
#  'headers',
#  'etag',
#  'updated',
#  'updated_parsed',
#  'href',
#  'status',
#  'encoding',
#  'version',
#  'namespaces']

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
# access the keys inside feed element
feed_key = list(feed_oreilly.feed.keys())

# %%
# print the of elements inside feed
feed_key
# Out:
# ['title',
#  'title_detail',
#  'id',
#  'guidislink',
#  'link',
#  'updated',
#  'updated_parsed',
#  'subtitle',
#  'subtitle_detail',
#  'links',
#  'authors',
#  'author_detail',
#  'author',
#  'feedburner_info',
#  'geo_lat',
#  'geo_long',
#  'feedburner_emailserviceid',
#  'feedburner_feedburnerhostname']

# %%
# we can call each one of this elements 
print(feed_oreilly.feed.title)
print(feed_oreilly.feed.author)
print(feed_oreilly.feed.geo_lat)
# Out:
# All - O'Reilly Media
# O'Reilly Media
# 38.393314

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %% [markdown]
# * Extract nested information in nested atributes

# %%
title = feed_oreilly.feed.title
subtitle = feed_oreilly.feed.subtitle
author = feed_oreilly.feed.author
link = feed_oreilly.feed.link

# %%
# print the atributes
print(f'Title:{title}, \nSubtitle:{subtitle}, \nAuthor:{author}, \nLink:{link}')
# Out:
# Title:All - O'Reilly Media,
# Subtitle:All of our Ideas and Learning material from all of our topics.,
# Author:O'Reilly Media,
# Link:https://www.oreilly.com

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
# Print the number of entries
len(feed_oreilly.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
# select the first element from feed_oreilly.entries and call the keys() function
entries_key = feed_oreilly.entries[0].keys()

# %%
# convert the dict_keys into a list
entries_key = list(entries_key)

# %%
entries_key
# Out:
# ['title',
#  'title_detail',
#  'updated',
#  'updated_parsed',
#  'id',
#  'guidislink',
#  'link',
#  'content',
#  'summary',
#  'links',
#  'authors',
#  'author_detail',
#  'author',
#  'feedburner_origlink']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %% [markdown]
# * We need a for/loop to extract all nested titles within entries

# %%
# iterate through each element and return the 'title' from each entry
titles = [entry['title'] 
          for entry in feed_oreilly.entries]

# %%
titles
# Out:
# ['Four short links: 19 July 2019',
#  'The war for the soul of open source',
#  'Ask not what Brands™ can do for you',
#  'O’Reilly Radar: Open source technology trends—What our users tell us',
#  "O'Reilly Open Source and Frank Willison Awards",
#  'Managing machines',
#  'Acquiring and sharing high-quality data',
#  'Four short links: 18 July 2019',
#  'Better living through software',
#  'Built to last: Building and growing open source communities',
#  'The next age of open innovation',
#  "Highlights from the O'Reilly Open Source Software Conference in Portland 2019",
#  'The role of open source in mitigating natural disasters',
#  'Why Amazon cares about open source',
#  'Four short links: 17 July 2019',
#  'Four short links: 16 July 2019',
#  'Managing machine learning in the enterprise: Lessons from banking and health care',
#  'Four short links: 15 July 2019',
#  'Four short links: 12 July 2019',
#  'Four short links: 11 July 2019',
#  'Four short links: 10 July 2019',
#  'Four short links: 9 July 2019',
#  'The circle of fairness',
#  "Highlights from the O'Reilly Artificial Intelligence Conference in Beijing 2019",
#  'Toward learned algorithms, data structures, and systems',
#  'Top AI breakthroughs you need to know',
#  'AI and retail',
#  'The future of hiring and the talent market with AI',
#  'AI and systems at RISELab',
#  'Data orchestration for AI, big data, and cloud',
#  'Designing computer hardware for artificial intelligence',
#  'The future of machine learning is tiny',
#  'Four short links: 8 July 2019',
#  'Four short links: 5 July 2019',
#  'Four short links: 4 July 2019',
#  'Tools for machine learning development',
#  'New live online training courses',
#  'Four short links: 3 July 2019',
#  'Four short links: 2 July 2019',
#  'Four short links: 1 July 2019',
#  'RISELab’s AutoPandas hints at automation tech that will change the nature of software development',
#  'Four short links: 28 June 2019',
#  'One simple chart: Who is interested in Spark NLP?',
#  'Four short links: 27 June 2019',
#  'Four short links: 26 June 2019',
#  'AI and machine learning will require retraining your entire organization',
#  'Four short links: 25 June 2019',
#  'Four short links: 24 June 2019',
#  'Four short links: 21 June 2019',
#  'Four short links: 20 June 2019',
#  'Enabling end-to-end machine learning pipelines in real-world applications',
#  'Four short links: 19 June 2019',
#  'What are model governance and model operations?',
#  'Four short links: 18 June 2019',
#  'The quest for high-quality data',
#  'Four short links: 17 June 2019',
#  'Prioritizing technical debt as if time and money mattered',
#  'From the trenches with Rebecca Parsons',
#  'Choices of scale',
#  'Four short links: 14 June 2019']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
# search for an element inside a list
four_short_links = [
    # return title
    title
    # iterate throght each element in title
    for title in titles
    # if the title contains 'For short links'
    if "Four short links" in title]

# %%
four_short_links
# Out:
# ['Four short links: 19 July 2019',
#  'Four short links: 18 July 2019',
#  'Four short links: 17 July 2019',
#  'Four short links: 16 July 2019',
#  'Four short links: 15 July 2019',
#  'Four short links: 12 July 2019',
#  'Four short links: 11 July 2019',
#  'Four short links: 10 July 2019',
#  'Four short links: 9 July 2019',
#  'Four short links: 8 July 2019',
#  'Four short links: 5 July 2019',
#  'Four short links: 4 July 2019',
#  'Four short links: 3 July 2019',
#  'Four short links: 2 July 2019',
#  'Four short links: 1 July 2019',
#  'Four short links: 28 June 2019',
#  'Four short links: 27 June 2019',
#  'Four short links: 26 June 2019',
#  'Four short links: 25 June 2019',
#  'Four short links: 24 June 2019',
#  'Four short links: 21 June 2019',
#  'Four short links: 20 June 2019',
#  'Four short links: 19 June 2019',
#  'Four short links: 18 June 2019',
#  'Four short links: 17 June 2019',
#  'Four short links: 14 June 2019']

# %%
# calculate the percentage ofr elements with 'Four short links'
perct = 100 * len(four_short_links) / len(titles)

# %%
print(f'"Four short links" represents {round(perct,2)}% of the list')
# Out:
# "Four short links" represents 43.33% of the list

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
# The dict format is a perfect match to be read with DataFrame() from pandas
df_entries = pd.DataFrame(feed_oreilly.entries)

# %%
df_entries.head(1)
# Out:
#            author               author_detail                       authors  \
# 0  Nat Torkington  {'name': 'Nat Torkington'}  [{'name': 'Nat Torkington'}]
#
#                                              content  \
# 0  [{'type': 'text/html', 'language': None, 'base...
#
#                                  feedburner_origlink  guidislink  \
# 0  https://www.oreilly.com/ideas/four-short-links...        True
#
#                                                   id  \
# 0  tag:www.oreilly.com,2019-07-19:/ideas/four-sho...
#
#                                                 link  \
# 0  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                links  \
# 0  [{'href': 'http://feedproxy.google.com/~r/orei...
#
#                                              summary  \
# 0  <p><em>Journal Mining, API Use, Better Convers...
#
#                             title  \
# 0  Four short links: 19 July 2019
#
#                                         title_detail               updated  \
# 0  {'type': 'text/plain', 'language': None, 'base...  2019-07-19T17:05:00Z
#
#                        updated_parsed
# 0  (2019, 7, 19, 17, 5, 0, 4, 200, 0)

# %% [markdown]
# * After creating the data frame, let's convert the 'updated' column into a datatime format

# %%
# write the string format accordingly to the 'updated' column
date_format = '%Y-%m-%d %H:%M:%S'

# %%
# create a new column 'datetime'
df_entries['datetime'] = pd.to_datetime(
    # call the pd.to_datetime passing the column and the format as an argument
    df_entries['updated'], format=date_format)

# %%
# check the number of posts by month using the dt.month argument
df_entries.datetime.dt.month.value_counts()
# Out:
# 7    41
# 6    19
# Name: datetime, dtype: int64

# %%
# check the number of posts by day of the week
df_entries.datetime.dt.weekday_name.value_counts()
# Out:
# Monday       16
# Wednesday    15
# Thursday     13
# Friday        9
# Tuesday       7
# Name: datetime, dtype: int64

# %% [markdown]
# * As we saw below, most of page's publications were posted on Mondays followed by Wednesdays

# %%
# Now let's check the time's publication
df_entries.datetime.dt.time.value_counts().head()
# Out:
# 20:00:00    11
# 15:50:00     8
# 11:00:00     7
# 08:00:00     3
# 10:45:00     3
# Name: datetime, dtype: int64

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
# grouping the entries by author and calling the size()
n_entries = df_entries.groupby(['author']).size()

# %%
# sort the entries at a descending order
n_entries = n_entries.sort_values(ascending=False)

# %%
n_entries.head()
# Out:
# author
# Nat Torkington                           26
# Ben Lorica                                5
# Ben Lorica, Harish Doddi, David Talby     2
# Jenn Webb                                 2
# VM Brasseur                               1
# dtype: int64

# %%
# we can write the code above in only one line
n_entries = df_entries.groupby(['author']).size().sort_values(ascending=False)

# %%
n_entries.head()
# Out:
# author
# Nat Torkington                           26
# Ben Lorica                                5
# Ben Lorica, Harish Doddi, David Talby     2
# Jenn Webb                                 2
# VM Brasseur                               1
# dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
# Method 1: calling len() using the str method over the column 'title'
df_entries['len_title'] = df_entries['title'].str.len()

# %%
# Method 2: using apply() and lambda
df_entries['len_title'] = df_entries.title.apply(
    lambda x: len(x))

# %%
# Select the 'author', 'title', and 'len_title' columns
columns_df = ['author', 'title', 'len_title']

# %%
# subset the dataset with the columns_df list
new_df_entries = df_entries[columns_df]

# %%
new_df_entries.head()
# Out:
#            author                                              title  \
# 0  Nat Torkington                     Four short links: 19 July 2019
# 1      Adam Jacob                The war for the soul of open source
# 2     VM Brasseur                Ask not what Brands™ can do for you
# 3  Roger Magoulas  O’Reilly Radar: Open source technology trends—...
# 4             NaN     O'Reilly Open Source and Frank Willison Awards
#
#    len_title
# 0         30
# 1         35
# 2         35
# 3         68
# 4         46

# %%
# sort df by 'len_title'
new_df_entries = new_df_entries.sort_values('len_title',
                                           ascending=False)

# %%
new_df_entries.head()
# Out:
#                                    author  \
# 40                             Ben Lorica
# 16  Ben Lorica, Harish Doddi, David Talby
# 23                              Jenn Webb
# 11                             Mac Slocum
# 50                             Ben Lorica
#
#                                                 title  len_title
# 40  RISELab’s AutoPandas hints at automation tech ...         97
# 16  Managing machine learning in the enterprise: L...         81
# 23  Highlights from the O'Reilly Artificial Intell...         79
# 11  Highlights from the O'Reilly Open Source Softw...         77
# 50  Enabling end-to-end machine learning pipelines...         73

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
# create a boolean mask filtering elements with 'machine learning'
mask = df_entries['summary'].str.contains('machine learning')

# %%
# subset the dataset
titles_ml = df_entries[mask]

# %%
# the new dataset contains 12 rows
titles_ml.shape
# Out:
# (12, 16)

# %%
# convert the titles which rows contains 'machine learning' to a list
titles_ml = list(titles_ml['title'])

# %%
titles_ml
# Out:
# ['Acquiring and sharing high-quality data',
#  "Highlights from the O'Reilly Open Source Software Conference in Portland 2019",
#  'Managing machine learning in the enterprise: Lessons from banking and health care',
#  "Highlights from the O'Reilly Artificial Intelligence Conference in Beijing 2019",
#  'The future of machine learning is tiny',
#  'Tools for machine learning development',
#  'New live online training courses',
#  'RISELab’s AutoPandas hints at automation tech that will change the nature of software development',
#  'AI and machine learning will require retraining your entire organization',
#  'Enabling end-to-end machine learning pipelines in real-world applications',
#  'What are model governance and model operations?',
#  'The quest for high-quality data']
